# %%
from pathlib import Path
import json
from enum import Enum
from faker import Faker
import sys
import random

# %%
working_directory = str(Path.cwd().parent)
if working_directory not in sys.path:
    sys.path.append(str(working_directory))
with open('../data/raw/train.json') as f:
    data = json.load(f)
num_of_tokens = sum([len(doc['tokens']) for doc in data])
possible_labels = ['O', 'B-NAME_STUDENT', 'I-NAME_STUDENT', 'B-URL_PERSONAL', 'B-ID_NUM',
                   'B-EMAIL', 'I-STREET_ADDRESS', 'I-PHONE_NUM', 'B-USERNAME', 'B-PHONE_NUM',
                   'B-STREET_ADDRESS', 'I-URL_PERSONAL', 'I-ID_NUM']
class Label(Enum):
    O = 'O'
    B_NAME_STUDENT = 'B-NAME_STUDENT'
    I_NAME_STUDENT = 'I-NAME_STUDENT'
    B_URL_PERSONAL = 'B-URL_PERSONAL'
    B_ID_NUM = 'B-ID_NUM'
    B_EMAIL = 'B-EMAIL'
    I_STREET_ADDRESS = 'I-STREET_ADDRESS'
    I_PHONE_NUM = 'I-PHONE_NUM'
    B_USERNAME = 'B-USERNAME'
    B_PHONE_NUM = 'B-PHONE_NUM'
    B_STREET_ADDRESS = 'B-STREET_ADDRESS'
    I_URL_PERSONAL = 'I-URL_PERSONAL'
    I_ID_NUM = 'I-ID_NUM'

def generate_fake_label(label, faker):
    if 'NAME_STUDENT' in label:
        return faker.name().split(' ')
    elif 'EMAIL' in label:
        return [faker.email()]
    elif 'USERNAME' in label:
        return [faker.user_name()]
    elif 'ID_NUM' in label:
        return [f"{faker.random_int(min=100000000000, max=999999999999):012d}"]
    elif 'URL_PERSONAL' in label:
        full_name = faker.name().split(' ')
        return [random.choice([f"{faker.url()}{full_name[0]}_{full_name[1]}", f"{faker.url()}{faker.user_name()}", f"http://{faker.user_name()}.com"])]
    elif 'PHONE_NUM' in label:
        return [faker.phone_number()]
    elif 'ADDRESS' in label:
        return [faker.address().split(' ')]

# %%
len(data)
# Out:
# 6807

# %%
data[1].keys()
# Out:
# dict_keys(['document', 'full_text', 'tokens', 'trailing_whitespace', 'labels'])

# %%
essays_with_labels_dict = {}
for essay in data:
    if not all(list(map(lambda label: label=='O', essay['labels']))):
        essays_with_labels_dict[essay['document']] = {'labels': essay['labels'], 'tokens': essay['tokens']}

# %%
essays_with_labels_dict[7].keys()
# Out:
# dict_keys(['labels', 'tokens'])

# %%
indices_of_labels_per_essay = {}
tokens_per_doc_id = {}
labels_per_doc_id = {}
for doc_id in essays_with_labels_dict.keys():
    tokens_per_doc_id[doc_id] = essays_with_labels_dict[doc_id]['tokens']
    labels_per_doc_id[doc_id] = essays_with_labels_dict[doc_id]['labels']
    indices_of_labels = []
    essay = essays_with_labels_dict[doc_id]
    for i in range(len(essay['labels'])):
        if essay['labels'][i] != 'O':
            indices_of_labels.append(i)
    indices_of_labels_per_essay[doc_id] = indices_of_labels

# %%
for doc_id in indices_of_labels_per_essay.keys():
    print(f'{doc_id}: {indices_of_labels_per_essay[doc_id]}')
# Out:
# 7: [9, 10, 482, 483, 741, 742]
# 5796: [10, 11, 16, 17, 24, 28]
# 5811: [303, 322]
# 5816: [2, 3]
# 5830: [6, 7]
# 5840: [6, 7]
# 5855: [15, 16]
# 5874: [4, 5]
# 5896: [8, 9]
# 5902: [0, 1, 3]
# 5906: [0, 1, 430, 431]
# 5910: [3, 4]
# 5922: [3, 4]
# 5923: [0, 409]
# 5935: [690]
# 5944: [0, 1]
# 5952: [8, 9]
# 5964: [22]
# 6002: [0, 1]
# 6007: [888]
# 6023: [0, 1, 655, 656]
# 6027: [2, 3]
# 6049: [11, 12]
# 6057: [783, 784]
# 6064: [4]
# 6074: [9, 10]
# 6085: [5, 6]
# 6088: [6, 7]
# 6095: [2, 3]
# 6101: [0, 1]
# 6117: [62, 63]
# 6121: [0, 1]
# 6124: [906, 907]
# 6133: [20, 21]
# 6139: [0, 1]
# 6148: [21]
# 6155: [5, 6]
# 6169: [896, 897]
# 6171: [18, 19]
# 6174: [0, 1]
# 6187: [0, 1]
# 6194: [26]
# 6220: [7]
# 6243: [2, 3, 7, 11, 12, 13, 14, 433, 434, 438, 442, 443, 444, 445, 460, 461, 465, 469, 470, 471, 472]
# 6257: [23, 140]
# 6270: [0, 1, 342, 343]
# 6282: [8, 9]
# 6296: [0, 1]
# 6319: [0, 1, 386, 387]
# 6339: [0, 1, 527, 528]
# 6348: [0, 1]
# 6353: [756, 757]
# 6364: [5, 6, 646, 647]
# 6378: [0, 1, 531, 532, 1077, 1078]
# 6393: [3, 4]
# 6416: [3, 4]
# 6426: [293, 295]
# 6432: [7, 8]
# 6435: [9, 10]
# 6450: [9, 10, 16, 17, 25, 32]
# 6457: [10, 11, 328]
# 6459: [4, 5]
# 6465: [1, 2]
# 6489: [873, 874]
# 6497: [5, 6, 485, 486, 956, 957]
# 6517: [0, 1]
# 6531: [0, 1]
# 6537: [9, 10, 12, 19, 21, 28, 30, 37, 193, 388]
# 6557: [14, 106]
# 6577: [0, 1, 3, 631, 632, 634]
# 6591: [9, 10, 12, 298, 299, 445, 446, 448]
# 6595: [10, 11]
# 6600: [1071, 1072]
# 6611: [0, 1, 3, 5]
# 6622: [0, 1]
# 6632: [0, 1]
# 6647: [5, 6]
# 6657: [7, 8]
# 6665: [5, 6]
# 6681: [4, 5]
# 6686: [927, 928]
# 6694: [10, 11, 38, 39, 62, 63, 69, 271, 520, 661, 837, 873, 878, 984, 1036, 1158, 1198, 1286]
# 6718: [9, 10, 853, 854]
# 6728: [0, 1]
# 6750: [9, 10]
# 6754: [723]
# 6769: [2, 3]
# 6775: [2, 3]
# 6784: [733, 1846, 1847]
# 6790: [0, 1]
# 6808: [0]
# 6830: [1066, 1067]
# 6849: [14, 15, 16]
# 6853: [988, 989, 993]
# 6859: [3, 4, 6]
# 6874: [15, 16]
# 6888: [5, 6]
# 6898: [12, 13, 23, 24, 400, 401]
# 6900: [7, 8, 12, 464, 465, 469]
# 6904: [414, 415]
# 6921: [5, 6, 582, 583]
# 6941: [5, 6]
# 6946: [20, 21]
# 6954: [439, 440]
# 6973: [0, 1, 895, 896, 901, 902]
# 6976: [6, 7, 785, 786]
# 6999: [640, 641, 644]
# 7000: [444]
# 7003: [12]
# 7006: [11]
# 7022: [0, 1]
# 7025: [0, 1]
# 7034: [311, 312, 745, 746]
# 7037: [5, 6]
# 7065: [2, 3]
# 7075: [7, 8]
# 7084: [8, 9, 10]
# 7098: [0, 1]
# 7115: [19, 20]
# 7124: [0, 1]
# 7137: [21, 22]
# 7156: [2, 3, 6, 16, 23, 32, 33, 40]
# 7176: [0, 1]
# 7197: [0, 1, 922, 923]
# 7203: [0, 1]
# 7222: [2, 3]
# 7236: [9]
# 7250: [8, 9]
# 7256: [5, 6]
# 7262: [689, 690]
# 7265: [0, 1]
# 7271: [20, 21]
# 7293: [6, 7, 8, 9]
# 7308: [0, 1, 3, 5, 7, 377, 378, 380, 382, 384]
# 7319: [13, 14]
# 7321: [9, 10]
# 7332: [4, 5]
# 7352: [2, 3]
# 7382: [0, 1, 321, 322]
# 7404: [288]
# 7408: [17]
# 7411: [401, 402]
# 7427: [0, 1, 306, 307]
# 7438: [4, 5]
# 7458: [16, 17]
# 7469: [0, 1, 453, 454]
# 7490: [5, 6]
# 7504: [10, 11]
# 7516: [0, 1]
# 7537: [753, 754]
# 7548: [0, 1, 393, 394, 534, 535]
# 7581: [0, 1, 412, 413]
# 7591: [9, 10]
# 7604: [283, 284]
# 7632: [6, 7]
# 7645: [14]
# 7663: [7, 8]
# 7668: [13, 14]
# 7676: [28, 29, 30]
# 7680: [31, 32, 76, 413]
# 7697: [0, 1]
# 7708: [25]
# 7713: [15, 16]
# 7730: [6, 7]
# 7733: [1037]
# 7735: [6, 7]
# 7745: [0, 1, 904, 905, 1842, 1843, 2459, 2460, 2462, 2463]
# 7754: [617, 618]
# 7763: [0, 1]
# 7770: [1, 2, 505, 506, 619, 620]
# 7779: [540, 588, 589, 634, 653, 654, 740, 741, 754, 755, 823, 824]
# 7786: [620, 621, 623]
# 7795: [7, 8]
# 7804: [1297, 1298, 2355, 2356]
# 7812: [5, 6]
# 7834: [10, 11]
# 7839: [5, 6]
# 7849: [7, 8]
# 7858: [5, 6, 857, 858]
# 7865: [0, 1]
# 7867: [7, 8]
# 7880: [501, 502]
# 7886: [0, 1]
# 7909: [624, 625]
# 7929: [6, 7]
# 7932: [24, 25, 528, 529, 750, 751, 757, 758]
# 7944: [8, 9]
# 7959: [2, 3]
# 7974: [3, 4]
# 7993: [0, 3, 4, 621]
# 8009: [13, 14]
# 8011: [645]
# 8021: [15, 16]
# 8028: [5, 6]
# 8033: [0, 1]
# 8070: [0, 1]
# 8076: [189]
# 8095: [8]
# 8108: [191]
# 8123: [461]
# 8127: [6]
# 8139: [40, 180]
# 8165: [2, 3, 318, 319]
# 8192: [3, 4, 22, 23, 381, 382]
# 8229: [0, 1, 468, 469]
# 8236: [133, 134]
# 8251: [5, 6]
# 8266: [0, 1, 839, 840]
# 8271: [6, 7]
# 8296: [0, 1, 527, 528]
# 8302: [3, 4]
# 13299: [10, 11]
# 13308: [731, 732]
# 13311: [21, 22, 23, 283, 284, 285]
# 13315: [585]
# 13317: [12]
# 13336: [2, 3]
# 13342: [0, 1, 523, 524]
# 14484: [294]
# 15717: [365, 964]
# 19280: [54, 55]
# 20984: [6]

# %%
def group_close_numbers(original_list, threshold=100):
    result = []
    current_group = []

    for num in original_list:
        if not current_group or num - current_group[-1] <= threshold:
            current_group.append(num)
        else:
            result.append(current_group)
            current_group = [num]

    if current_group:
        result.append(current_group)

    return result

# %%
indices_of_labels_per_essay_groups = {}
for doc_id in indices_of_labels_per_essay:
    indices_of_labels_per_essay_groups[doc_id] = group_close_numbers(indices_of_labels_per_essay[doc_id])

# %%
indices_of_labels_per_essay_groups
# Out:
# {7: [[9, 10], [482, 483], [741, 742]],
#  10: [[0, 1], [464, 465]],
#  16: [[4, 5]],
#  20: [[5, 6]],
#  56: [[12, 13]],
#  86: [[6, 7]],
#  93: [[0, 1]],
#  104: [[8, 9]],
#  112: [[5, 6]],
#  123: [[32, 33]],
#  136: [[30]],
#  166: [[0, 1]],
#  204: [[4]],
#  214: [[4, 5]],
#  269: [[783, 784]],
#  288: [[0, 1]],
#  308: [[0, 1], [591, 592], [1206, 1207], [1502, 1503]],
#  317: [[611]],
#  324: [[13]],
#  330: [[18, 19]],
#  333: [[20, 21]],
#  344: [[7, 8]],
#  356: [[701, 702]],
#  375: [[5, 6]],
#  379: [[15, 16, 28, 31], [760, 761]],
#  470: [[0]],
#  472: [[4, 5], [922]],
#  591: [[3, 4]],
#  607: [[478, 479]],
#  609: [[19,
#    20,
#    26,
#    32,
#    33,
#    39,
#    50,
#    53,
#    54,
#    56,
#    62,
#    65,
#    66,
#    68,
#    71,
#    72,
#    74,
#    77,
#    78,
#    80,
#    83,
#    84,
#    89,
#    92,
#    93,
#    125]],
#  616: [[0, 1]],
#  651: [[0, 1], [611, 612]],
#  659: [[0, 1]],
#  671: [[13]],
#  714: [[3, 4]],
#  730: [[3, 4, 6, 7, 12, 13]],
#  736: [[17, 18]],
#  760: [[8, 9]],
#  828: [[9, 10]],
#  1105: [[5, 6, 56, 93, 155, 194, 226, 239], [580]],
#  1134: [[11, 12]],
#  1175: [[0, 1]],
#  1185: [[6, 7]],
#  1210: [[12, 13]],
#  1221: [[0, 1]],
#  1239: [[9, 10]],
#  1277: [[0, 1], [503, 504]],
#  1290: [[556, 557, 601, 602]],
#  1295: [[5, 6]],
#  1309: [[497]],
#  1325: [[14, 15, 16, 17]],
#  1353: [[9, 10], [438, 439]],
#  1437: [[6, 7]],
#  1444: [[12, 13]],
#  1447: [[746, 747]],
#  1472: [[826, 827]],
#  1477: [[0, 1]],
#  1546: [[5, 6], [629, 630]],
#  1549: [[0, 1]],
#  1578: [[3, 4]],
#  1613: [[7, 8]],
#  1753: [[248, 249]],
#  1758: [[5, 6]],
#  1763: [[13]],
#  1769: [[11, 12]],
#  1790: [[9, 10]],
#  1795: [[0, 1], [832, 833]],
#  1798: [[70, 71], [292]],
#  1802: [[0, 1], [751, 752], [1291, 1292]],
#  1810: [[15, 16]],
#  1814: [[7, 8]],
#  1817: [[5, 6]],
#  1824: [[828, 829]],
#  2054: [[714, 715]],
#  2058: [[9, 10]],
#  2061: [[8, 9]],
#  2335: [[5, 6], [360, 361]],
#  2651: [[0, 1], [625, 626]],
#  2660: [[0, 1]],
#  2672: [[9, 10], [269]],
#  2694: [[7, 8]],
#  2700: [[825]],
#  2711: [[3, 4]],
#  2722: [[10, 11],
#   [113, 114, 137, 222],
#   [346],
#   [460],
#   [573],
#   [674, 726, 736, 737, 777, 809, 880, 952, 984, 1047, 1081],
#   [1325]],
#  2732: [[10]],
#  2745: [[2, 3]],
#  2769: [[19, 20, 22]],
#  2780: [[726, 727]],
#  2790: [[21, 22]],
#  2792: [[2, 3], [222, 223], [804, 805]],
#  2797: [[7, 8]],
#  2802: [[6, 7]],
#  2804: [[0, 1]],
#  2813: [[0, 1]],
#  2828: [[4, 5], [605, 606]],
#  2842: [[578, 579]],
#  2882: [[5, 6]],
#  2901: [[0, 1], [583, 584], [988, 989]],
#  2915: [[30, 31, 46, 47]],
#  2926: [[2, 3, 9]],
#  2955: [[961, 962]],
#  2995: [[13, 14]],
#  3003: [[0, 1]],
#  3202: [[23, 24, 31, 33, 34, 36, 37]],
#  3211: [[8, 9]],
#  3214: [[248, 261, 297, 312, 342, 399]],
#  3231: [[13, 14]],
#  3241: [[632]],
#  3249: [[7, 8]],
#  3275: [[4, 5]],
#  3294: [[0, 1]],
#  3318: [[0, 1]],
#  3328: [[5, 6]],
#  3350: [[0, 1]],
#  3351: [[61]],
#  3380: [[2], [538]],
#  3391: [[4, 5]],
#  3402: [[1224]],
#  3423: [[11, 12]],
#  3427: [[6, 7, 23, 24], [505, 506], [1125, 1126], [1709, 1710]],
#  3446: [[8, 9]],
#  3538: [[5, 6]],
#  3540: [[6, 7]],
#  3553: [[0, 1]],
#  3565: [[12, 13, 18, 19, 26, 33]],
#  3579: [[5, 6]],
#  3586: [[4, 5]],
#  3592: [[55]],
#  3603: [[6, 7]],
#  3652: [[2, 3]],
#  3664: [[10, 11]],
#  3678: [[9, 10, 11]],
#  3686: [[0, 1], [1434, 1435]],
#  3699: [[573, 574]],
#  3709: [[19, 27, 28, 30, 31, 33, 34, 36, 37, 53, 55], [796], [1777], [2272]],
#  3732: [[0, 1]],
#  3736: [[0, 1, 2]],
#  3743: [[2, 3]],
#  3756: [[2, 3]],
#  3759: [[0, 1], [405, 406]],
#  3786: [[0, 1]],
#  3803: [[386, 387]],
#  3835: [[9, 10]],
#  3882: [[3, 4], [270, 271]],
#  3885: [[1, 2, 63, 76, 153, 172], [303], [409, 411, 417, 482, 483]],
#  3892: [[4, 5]],
#  3894: [[7, 8, 34]],
#  3900: [[7, 8]],
#  3911: [[0, 1], [455, 456], [697, 698]],
#  3915: [[0, 1], [557, 558], [1168, 1169, 1177, 1178]],
#  3921: [[8, 9]],
#  3935: [[28, 29], [592, 593]],
#  7084: [[8, 9, 10]],
#  7098: [[0, 1]],
#  7115: [[19, 20]],
#  7124: [[0, 1]],
#  7137: [[21, 22]],
#  7156: [[2, 3, 6, 16, 23, 32, 33, 40]],
#  7176: [[0, 1]],
#  7197: [[0, 1], [922, 923]],
#  7203: [[0, 1]],
#  7222: [[2, 3]],
#  7236: [[9]],
#  7250: [[8, 9]],
#  7256: [[5, 6]],
#  7262: [[689, 690]],
#  7265: [[0, 1]],
#  7271: [[20, 21]],
#  7293: [[6, 7, 8, 9]],
#  7308: [[0, 1, 3, 5, 7], [377, 378, 380, 382, 384]],
#  7319: [[13, 14]],
#  7321: [[9, 10]],
#  7332: [[4, 5]],
#  7352: [[2, 3]],
#  7382: [[0, 1], [321, 322]],
#  7404: [[288]],
#  7408: [[17]],
#  7411: [[401, 402]],
#  7427: [[0, 1], [306, 307]],
#  7438: [[4, 5]],
#  7458: [[16, 17]],
#  7469: [[0, 1], [453, 454]],
#  7490: [[5, 6]],
#  7504: [[10, 11]],
#  7516: [[0, 1]],
#  7537: [[753, 754]],
#  7548: [[0, 1], [393, 394], [534, 535]],
#  7581: [[0, 1], [412, 413]],
#  7591: [[9, 10]],
#  7604: [[283, 284]],
#  7632: [[6, 7]],
#  7645: [[14]],
#  7663: [[7, 8]],
#  7668: [[13, 14]],
#  7676: [[28, 29, 30]],
#  7680: [[31, 32, 76], [413]],
#  7697: [[0, 1]],
#  7708: [[25]],
#  7713: [[15, 16]],
#  7730: [[6, 7]],
#  7733: [[1037]],
#  7735: [[6, 7]],
#  7745: [[0, 1], [904, 905], [1842, 1843], [2459, 2460, 2462, 2463]],
#  7754: [[617, 618]],
#  7763: [[0, 1]],
#  7770: [[1, 2], [505, 506], [619, 620]],
#  7779: [[540, 588, 589, 634, 653, 654, 740, 741, 754, 755, 823, 824]],
#  7786: [[620, 621, 623]],
#  7795: [[7, 8]],
#  7804: [[1297, 1298], [2355, 2356]],
#  7812: [[5, 6]],
#  7834: [[10, 11]],
#  7839: [[5, 6]],
#  7849: [[7, 8]],
#  7858: [[5, 6], [857, 858]],
#  7865: [[0, 1]],
#  7867: [[7, 8]],
#  7880: [[501, 502]],
#  7886: [[0, 1]],
#  7909: [[624, 625]],
#  7929: [[6, 7]],
#  7932: [[24, 25], [528, 529], [750, 751, 757, 758]],
#  7944: [[8, 9]],
#  7959: [[2, 3]],
#  7974: [[3, 4]],
#  7993: [[0, 3, 4], [621]],
#  8009: [[13, 14]],
#  8011: [[645]],
#  8021: [[15, 16]],
#  8028: [[5, 6]],
#  8033: [[0, 1]],
#  8070: [[0, 1]],
#  8076: [[189]],
#  8095: [[8]],
#  8108: [[191]],
#  8123: [[461]],
#  8127: [[6]],
#  8139: [[40], [180]],
#  8165: [[2, 3], [318, 319]],
#  8192: [[3, 4, 22, 23], [381, 382]],
#  8229: [[0, 1], [468, 469]],
#  8236: [[133, 134]],
#  8251: [[5, 6]],
#  8266: [[0, 1], [839, 840]],
#  8271: [[6, 7]],
#  8296: [[0, 1], [527, 528]],
#  8302: [[3, 4]],
#  8316: [[0, 1], [520, 521], [1303, 1304]],
#  8329: [[19, 20]],
#  8335: [[3, 4]],
#  8340: [[2, 3, 6, 7]],
#  8344: [[0, 1, 14, 47]],
#  8349: [[4, 5]],
#  8364: [[0, 1]],
#  8371: [[3, 4]],
#  8379: [[432, 433], [563, 564]],
#  8393: [[6, 7], [735, 736]],
#  8416: [[7, 8], [365]],
#  8435: [[626]],
#  8447: [[7, 8]],
#  8467: [[1, 2]],
#  8474: [[9, 10]],
#  8480: [[16, 94, 169, 252]],
#  8485: [[5, 6]],
#  8491: [[462]],
#  8505: [[1460, 1461]],
#  8518: [[17, 18]],
#  8545: [[0, 1], [456, 457]],
#  8550: [[6, 7]],
#  8562: [[5, 6]],
#  8575: [[38, 39]],
#  8578: [[18, 19]],
#  8584: [[8, 9]],
#  8593: [[0, 1], [547, 548]],
#  8603: [[647, 648]],
#  8609: [[6, 7]],
#  8612: [[6, 7, 8]],
#  8621: [[9, 10, 11]],
#  8631: [[0, 1]],
#  8642: [[0, 1, 2, 4, 8]],
#  8652: [[1211, 1212]],
#  8669: [[8, 9]],
#  8672: [[10, 11]],
#  8674: [[8, 9], [529, 530], [1057, 1058]],
#  8688: [[375]],
#  8690: [[4]],
#  8699: [[18]],
#  8711: [[4, 5]],
#  8714: [[8, 10]],
#  8718: [[8, 22, 24, 47, 72, 91, 124, 160, 176, 197, 279, 368, 385, 391]],
#  8733: [[0, 1]],
#  8747: [[5, 6, 29, 57], [736]],
#  8751: [[706, 710, 711]],
#  8762: [[32]],
#  8768: [[5, 6]],
#  8776: [[875, 876]],
#  8798: [[529], [641]],
#  8805: [[0, 1]],
#  8811: [[8, 9]],
#  8842: [[0, 1]],
#  8846: [[11, 12]],
#  8863: [[8, 9]],
#  8880: [[21]],
#  8894: [[16, 17]],
#  8909: [[456]],
#  8918: [[0, 1]],
#  8925: [[7, 8]],
#  8950: [[4, 5]],
#  8962: [[12, 13]],
#  8982: [[3, 4]],
#  9009: [[4, 5]],
#  9018: [[207]],
#  9028: [[609, 610]],
#  9043: [[201, 287]],
#  9050: [[4, 5, 39, 116, 124, 149, 196], [314]],
#  9103: [[9, 10]],
#  9109: [[3, 4]],
#  9127: [[536, 537]],
#  9138: [[6, 7, 84]],
#  9146: [[66, 67, 69, 72, 84, 85], [245, 246, 248, 251]],
#  9151: [[3, 4]],
#  9161: [[2, 3]],
#  9188: [[8, 9], [701, 702], [1514, 1515], [2320, 2321]],
#  9203: [[10, 11], [573, 574]],
#  9208: [[714, 715]],
#  9215: [[7, 8]],
#  9219: [[11, 12]],
#  9243: [[12, 13]],
#  9260: [[3, 4]],
#  9268: [[0, 1]],
#  9281: [[796, 797]],
#  9286: [[371], [572, 605], [725]],
#  9289: [[0, 1], [612, 613]],
#  9297: [[608, 609], [1042, 1069, 1072]],
#  9324: [[503, 512, 533]],
#  9336: [[5, 6], [463, 464], [814, 815]],
#  9348: [[0, 1]],
#  9358: [[13], [479]],
#  12626: [[0, 1]],
#  12634: [[33, 34]],
#  12658: [[0, 1]],
#  12662: [[0, 1]],
#  12673: [[0, 1]],
#  12679: [[0, 1]],
#  12705: [[4, 5], [474, 475], [991, 992]],
#  12723: [[1038, 1039]],
#  12749: [[5, 6]],
#  12755: [[0, 1]],
#  12771: [[0, 1]],
#  12774: [[290]],
#  12782: [[25, 26], [538, 539]],
#  12791: [[0]],
#  12803: [[17, 18]],
#  12812: [[12, 13], [593, 594]],
#  12828: [[16, 17]],
#  12836: [[0, 1]],
#  12843: [[6, 7]],
#  12852: [[0, 1]],
#  12859: [[5, 6]],
#  12876: [[2, 3]],
#  12888: [[15, 16], [3288, 3289]],
#  12899: [[2, 3]],
#  12941: [[0, 1]],
#  12956: [[10, 11]],
#  12962: [[3, 4]],
#  12970: [[10, 11]],
#  12989: [[3, 4, 6]],
#  12995: [[13, 14]],
#  12998: [[0, 1], [646, 647], [1416, 1417]],
#  13005: [[0]],
#  13007: [[0, 1], [449, 450]],
#  13017: [[0, 1]],
#  13024: [[3, 4]],
#  13039: [[6, 7]],
#  13047: [[4, 5]],
#  13066: [[5, 6]],
#  13086: [[9, 10]],
#  13100: [[672, 673]],
#  13103: [[63, 66, 144, 147], [455, 457], [649, 651]],
#  13115: [[5, 6]],
#  13121: [[0, 1], [745, 746]],
#  13131: [[4, 5]],
#  13133: [[5, 6]],
#  13144: [[461, 462, 498, 499]],
#  13158: [[6, 7]],
#  13190: [[24, 25]],
#  13198: [[0, 1]],
#  13210: [[6, 7]],
#  13219: [[0, 1]],
#  13223: [[0, 1]],
#  13228: [[0, 1]],
#  13236: [[7, 8]],
#  13244: [[0, 1]],
#  13249: [[271, 287, 344, 349, 369, 396, 442, 451, 516, 570],
#   [766, 839, 873, 881, 926, 947, 958, 964, 969, 983, 1009, 1024]],
#  13260: [[6, 7]],
#  13273: [[0, 1]],
#  13276: [[5, 6]],
#  13293: [[0, 1]],
#  13299: [[10, 11]],
#  13308: [[731, 732]],
#  13311: [[21, 22, 23], [283, 284, 285]],
#  13315: [[585]],
#  13317: [[12]],
#  13336: [[2, 3]],
#  13342: [[0, 1], [523, 524]],
#  14484: [[294]],
#  15717: [[365], [964]],
#  19280: [[54, 55]],
#  20984: [[6]]}

# %%
def get_window(group_of_indices, tokens):
    stopping_tokens = ['\n\n', '\n']
    left = max(0, group_of_indices[0] - 100)
    right = min(len(tokens) - 1, group_of_indices[-1])
    previous_progres = 0
    for progress, token in enumerate(tokens[left:group_of_indices[0]]):
        if token in stopping_tokens:
            left += (progress - previous_progres)
            previous_progres = progress
    
    for _ in range(len(tokens) - 1 - right):
        if tokens[right] in ['.']:
            break
        else:
            right += 1
    
    return [left, right]

# %%
windows_per_doc_id = {}
for doc_id in indices_of_labels_per_essay_groups.keys():
    indices_of_labels_per_essay_windows = []
    for group in indices_of_labels_per_essay_groups[doc_id]:
        indices_of_labels_per_essay_windows.append(get_window(group, tokens_per_doc_id[doc_id]))
    windows_per_doc_id[doc_id] = indices_of_labels_per_essay_windows

# %%
windows_per_doc_id
# Out:
# {7: [[0, 38], [472, 515], [731, 752]],
#  10: [[0, 30], [463, 475]],
#  16: [[2, 28]],
#  20: [[4, 61]],
#  56: [[0, 106]],
#  86: [[0, 35]],
#  93: [[0, 21]],
#  104: [[6, 44]],
#  112: [[4, 21]],
#  123: [[31, 64]],
#  136: [[29, 63]],
#  166: [[0, 31]],
#  204: [[0, 23]],
#  214: [[3, 48]],
#  269: [[782, 785]],
#  288: [[0, 47]],
#  308: [[0, 42], [590, 604], [1205, 1254], [1501, 1698]],
#  317: [[582, 623]],
#  324: [[9, 21]],
#  330: [[17, 79]],
#  333: [[16, 46]],
#  344: [[0, 69]],
#  356: [[700, 711]],
#  375: [[0, 53]],
#  379: [[0, 64], [660, 765]],
#  470: [[0, 49]],
#  472: [[3, 16], [917, 943]],
#  591: [[0, 40]],
#  607: [[477, 480]],
#  609: [[8, 134]],
#  616: [[0, 4]],
#  651: [[0, 42], [610, 626]],
#  659: [[0, 9]],
#  671: [[10, 75]],
#  714: [[0, 94]],
#  730: [[0, 39]],
#  736: [[16, 24]],
#  760: [[7, 45]],
#  828: [[8, 60]],
#  1105: [[0, 267], [505, 604]],
#  1134: [[0, 23]],
#  1175: [[0, 24]],
#  1185: [[3, 44]],
#  1210: [[0, 25]],
#  1221: [[0, 47]],
#  1239: [[8, 11]],
#  1277: [[0, 38], [502, 526]],
#  1290: [[555, 677]],
#  1295: [[0, 7]],
#  1309: [[489, 513]],
#  1325: [[0, 20]],
#  1353: [[0, 43], [428, 513]],
#  1437: [[0, 33]],
#  1444: [[9, 34]],
#  1447: [[745, 754]],
#  1472: [[825, 828]],
#  1477: [[0, 68]],
#  1546: [[0, 44], [623, 673]],
#  1549: [[0, 43]],
#  1578: [[2, 37]],
#  1613: [[0, 30]],
#  1753: [[247, 265]],
#  1758: [[4, 44]],
#  1763: [[0, 14]],
#  1769: [[7, 30]],
#  1790: [[6, 39]],
#  1795: [[0, 54], [831, 855]],
#  1798: [[69, 106], [291, 293]],
#  1802: [[0, 74], [750, 797], [1290, 1315]],
#  1810: [[6, 19]],
#  1814: [[6, 36]],
#  1817: [[4, 23]],
#  1824: [[824, 830]],
#  2054: [[705, 716]],
#  2058: [[0, 38]],
#  2061: [[6, 56]],
#  2335: [[0, 47], [354, 385]],
#  2651: [[0, 49], [624, 656]],
#  2660: [[0, 44]],
#  2672: [[8, 31], [209, 288]],
#  2694: [[4, 45]],
#  2700: [[725, 853]],
#  2711: [[0, 35]],
#  2722: [[0, 61],
#   [99, 235],
#   [246, 354],
#   [399, 509],
#   [533, 664],
#   [574, 1155],
#   [1225, 1346]],
#  2732: [[6, 58]],
#  2745: [[0, 68]],
#  2769: [[15, 54]],
#  2780: [[725, 728]],
#  2790: [[19, 49]],
#  2792: [[0, 25], [219, 262], [801, 808]],
#  2797: [[5, 39]],
#  2802: [[5, 29]],
#  2804: [[0, 31]],
#  2813: [[0, 47]],
#  2828: [[3, 46], [604, 634]],
#  12564: [[7, 85], [404, 506]],
#  12565: [[0, 128]],
#  12578: [[4, 27]],
#  12585: [[0, 60]],
#  12595: [[4, 80], [574, 614]],
#  12603: [[0, 43]],
#  12615: [[0, 47]],
#  12626: [[0, 57]],
#  12634: [[17, 37]],
#  12658: [[0, 37]],
#  12662: [[0, 78]],
#  12673: [[0, 20]],
#  12679: [[0, 24]],
#  12705: [[3, 21], [473, 490], [990, 1023]],
#  12723: [[949, 1044]],
#  12749: [[0, 41]],
#  12755: [[0, 48]],
#  12771: [[0, 31]],
#  12774: [[229, 345]],
#  12782: [[21, 29], [534, 553]],
#  12791: [[0, 30]],
#  12803: [[13, 58]],
#  12812: [[11, 76], [592, 627]],
#  12828: [[2, 60]],
#  12836: [[0, 70]],
#  12843: [[5, 40]],
#  12852: [[0, 42]],
#  12859: [[4, 23]],
#  12876: [[1, 53]],
#  12888: [[14, 26], [3188, 3297]],
#  12899: [[0, 31]],
#  12941: [[0, 58]],
#  12956: [[9, 32]],
#  12962: [[0, 79]],
#  12970: [[7, 60]],
#  12989: [[2, 42]],
#  12995: [[0, 37]],
#  12998: [[0, 38], [645, 719], [1415, 1446]],
#  13005: [[0, 23]],
#  13007: [[0, 50], [448, 476]],
#  13017: [[0, 44]],
#  13024: [[2, 39]],
#  13039: [[3, 78]],
#  13047: [[3, 75]],
#  13066: [[4, 35]],
#  13086: [[0, 94]],
#  13100: [[668, 674]],
#  13103: [[5, 334], [445, 504], [642, 675]],
#  13115: [[4, 9]],
#  13121: [[0, 20], [744, 765]],
#  13131: [[0, 55]],
#  13133: [[3, 37]],
#  13144: [[457, 545]],
#  13158: [[5, 15]],
#  13190: [[23, 88]],
#  13198: [[0, 12]],
#  13210: [[3, 8]],
#  13219: [[0, 32]],
#  13223: [[0, 35]],
#  13228: [[0, 74]],
#  13236: [[0, 27]],
#  13244: [[0, 70]],
#  13249: [[176, 593], [749, 1038]],
#  13260: [[3, 27]],
#  13273: [[0, 45]],
#  13276: [[0, 9]],
#  13293: [[0, 51]],
#  13299: [[8, 22]],
#  13308: [[728, 737]],
#  13311: [[20, 48], [282, 297]],
#  13315: [[536, 586]],
#  13317: [[0, 33]],
#  13336: [[0, 22]],
#  13342: [[0, 28], [522, 559]],
#  14484: [[212, 316]],
#  15717: [[265, 372], [879, 975]],
#  19280: [[53, 89]],
#  20984: [[0, 19]]}

# %%
new_doc_id = 0
augmented_data = {}
for doc_id in windows_per_doc_id.keys():
    for window in windows_per_doc_id[doc_id]:
        augmented_data[new_doc_id] = {'tokens': tokens_per_doc_id[doc_id][window[0]:window[1]], 'labels': labels_per_doc_id[doc_id][window[0]:window[1]]}
        new_doc_id += 1

# %%
faker = Faker()
for doc_id in augmented_data:
    essay = augmented_data[doc_id]
    index = 0
    while index < len(essay['labels']):
        # print(index)
        if essay['labels'][index] != 'O':
            new_token = generate_fake_label(essay['labels'][index], faker)
            print(new_token)
            for i, new_token_part in enumerate(new_token):
                index += i
                if index >= len(essay['labels']):
                    break
                if essay['labels'][index] == 'O':
                    essay['tokens'].insert(index, new_token_part)
                    essay['labels'].insert(index, essay['labels'][index])
                else:
                    essay['tokens'][index] = new_token_part
        index += 1
# Out:
# ['Donald', 'Anderson']
# ['Ryan', 'King']
# ['Anthony', 'Barnes']
# ['Ricardo', 'Edwards']
# ['Justin', 'Hernandez']
# ['Joshua', 'Dawson']
# ['Amber', 'Franklin']
# ['Cynthia', 'Walters']
# ['Ian', 'White']
# ['Stephanie', 'Baker']
# ['Stephanie', 'Nichols']
# ['Joseph', 'Fritz']
# ['Jamie', 'Neal']
# ['Kristina', 'Hickman']
# ['Adrian', 'Gordon']
# ['Stephen', 'Wu']
# ['Erik', 'Davis']
# ['Kathy', 'King']
# ['Aaron', 'Conner']
# ['Cathy', 'Haynes']
# ['Shelia', 'Cole']
# ['Alexandria', 'Ortiz']
# ['Michael', 'Martin']
# ['https://strickland.biz/Troy_Woodward']
# ['Joseph', 'Washington']
# ['Steve', 'Wilson']
# ['Monica', 'Hudson']
# ['Timothy', 'Solis']
# ['Mark', 'Myers']
# ['Robert', 'Bowman']
# ['Jeffrey', 'Price']
# ['xsmith@example.com']
# ['http://www.stephenson-jensen.com/Kathleen_Gibson']
# ['Robert', 'Allen']
# ['John', 'Meadows']
# ['Jasmine', 'Taylor']
# ['http://stephen75.com']
# ['Elizabeth', 'Young']
# ['Jimmy', 'Jackson']
# ['Lisa', 'Hopkins']
# ['499415510555']
# ['Rebecca', 'Robertson']
# ['242802134753']
# ['291383014817']
# ['Erin', 'Garza']
# ['718333519727']
# ['810441850737']
# ['Mr.', 'James', 'Cortez']
# ['Rachel', 'Foster']
# ['369885749741']
# ['Scott', 'Bennett']
# ['213912542876']
# ['Joshua', 'Cummings']
# ['299613413640']
# ['Lauren', 'Ibarra']
# ['Gina', 'Williams']
# ['Anthony', 'Shaw']
# ['Brian', 'Mcdaniel']
# ['Sharon', 'Marshall']
# ['Elizabeth', 'Stuart']
# ['Bridget', 'Boyd']
# ['Bradley', 'Dunlap']
# ['Eric', 'Martinez', 'MD']
# ['James', 'Jacobs']
# ['Kendra', 'Hunter']
# ['Kimberly', 'Shelton']
# ['Christina', 'Taylor']
# ['Lauren', 'Johnson']
# ['Matthew', 'Michael']
# ['Lisa', 'Keith']
# ['Mr.', 'Paul', 'Murray', 'MD']
# ['Michael', 'Nelson']
# ['Richard', 'Irwin']
# ['Jennifer', 'Pitts']
# ['Jenna', 'Briggs']
# ['Jessica', 'Cole']
# ['Ryan', 'Thompson']
# ['Dylan', 'Atkins']
# ['Justin', 'Bright']
# ['Thomas', 'Miller']
# ['Alex', 'Higgins']
# ['Raven', 'Little']
# ['Erica', 'Turner']
# ['Joshua', 'Walters']
# ['Alex', 'Carrillo']
# ['Brian', 'Koch']
# ['Robert', 'Hernandez']
# ['http://gwendolynday.com']
# ['Bradley', 'Curtis']
# ['Mary', 'Collins']
# ['Tracy', 'Miller']
# ['Paul', 'King']
# ['Michelle', 'Howell']
# ['Brian', 'Johnson', 'MD']
# ['Andrew', 'Santos']
# ['Ryan', 'Carroll', 'PhD']
# ['Justin', 'Skinner']
# ['Chelsea', 'Gomez']
# ['Christopher', 'Parker']
# ['Craig', 'Taylor']
# ['Eric', 'Garrison']
# ['Deborah', 'Miller', 'DVM']
# ['Felicia', 'Marshall']
# ['Dana', 'Cowan']
# ['Jessica', 'Sullivan']
# ['Lisa', 'Koch']
# ['Miguel', 'Wolfe']
# ['Samuel', 'Blanchard']
# ['Melissa', 'Mitchell']
# ['Jamie', 'Smith']
# ['http://fitzpatrickbrandon.com']
# ['Brian', 'Wilson']
# ['Mr.', 'Brendan', 'Gonzales']
# ['John', 'Garcia']
# ['Sean', 'Medina']
# ['Brandi', 'Owens']
# ['Kenneth', 'Murphy']
# ['Patricia', 'Perez']
# ['Mandy', 'Williams']
# ['Tonya', 'Castillo']
# ['Sara', 'Nunez']
# ['Gabrielle', 'Anderson']
# ['Ms.', 'Ashley', 'Johnson']
# ['Frederick', 'Hughes']
# ['Garrett', 'Leon']
# ['James', 'Preston']
# ['Deborah', 'Bradley']
# ['http://www.lopez.com/thomas71']
# ['Jacob', 'Blackwell']
# ['http://andrewstravis.com']
# ['Gerald', 'Miranda']
# ['Angela', 'Murray']
# ['Maureen', 'Collins']
# ['Danielle', 'Alvarado']
# ['Jessica', 'Ramirez']
# ['Aaron', 'Hayes']
# ['Zachary', 'Hall']
# ['Katelyn', 'Vasquez']
# ['David', 'Brown']
# ['Steven', 'Ward']
# ['Aaron', 'Choi']
# ['Andrew', 'Holt']
# ['Samuel', 'Hayes']
# ['Mark', 'Sanders']
# ['Stephen', 'Martinez']
# ['Laura', 'Lopez']
# ['Brandi', 'Walker']
# ['Nicholas', 'Hayes']
# ['David', 'Baird']
# ['Nathaniel', 'Rowe']
# ['Manuel', 'Bowman']
# ['William', 'Woodward']
# ['browneric@example.com']
# ['Travis', 'Daniels']
# ['Miss', 'Jodi', 'Meyer']
# ['Mr.', 'Paul', 'Hall', 'DDS']
# ['David', 'Coleman']
# ['Jennifer', 'Holloway']
# ['Dwayne', 'Mooney']
# ['Eric', 'Norman']
# ['Jacob', 'Coleman']
# ['Jessica', 'Ayers']
# ['Ana', 'Serrano']
# ['Kimberly', 'Griffin']
# ['Amy', 'Reynolds']
# ['Crystal', 'Moore']
# ['Marcia', 'Garcia']
# ['Danielle', 'Sanders']
# ['Jennifer', 'Tucker']
# ['Cameron', 'Barnes']
# ['Jennifer', 'Henderson']
# ['Melanie', 'Mcdaniel']
# ['202427522002']
# ['Tyler', 'Martin']
# ['Charles', 'Miller']
# ['Anthony', 'Franklin']
# ['Frank', 'Gibson']
# ['http://clester.com']
# ['https://williams.biz/christine33']
# ['http://jacksonjoshua.com']
# ['Joyce', 'Smith']
# ['Kevin', 'Matthews']
# ['Thomas', 'Lee']
# ['Tracy', 'Mendez']
# ['Taylor', 'Moore']
# ['Troy', 'Martin']
# ['Troy', 'Wells']
# ['Bryan', 'Cole']
# ['Raymond', 'Richardson']
# ['Matthew', 'Rodriguez']
# ['Tommy', 'Schmidt']
# ['Matthew', 'Holloway']
# ['Karen', 'Hughes']
# ['Lisa', 'Sheppard']
# ['Ernest', 'Watkins']
# ['Matthew', 'Anderson']
# ['tyler49']
# ['Natasha', 'Watson']
# ['Linda', 'Robinson']
# ['Daniel', 'Hill']
# ['https://myers.info/phanson']
# ['Brandon', 'Obrien']
# ['Eric', 'Mcintosh', 'MD']
# ['Erica', 'Malone']
# ['Christine', 'Knapp']
# ['Amanda', 'Marks']
# ['Christopher', 'Lucas']
# ['Jennifer', 'Pham']
# ['Catherine', 'Medina']
# ['Samantha', 'Hammond']
# ['Brandon', 'Allen']
# ['Zoe', 'Barnes']
# ['Karen', 'Johnson']
# ['174373194037']
# ['897629282850']
# ['William', 'Price']
# ['Sabrina', 'Sparks']
# ['http://zedwards.com']
# ['Joseph', 'Fletcher', 'DVM']
# ['Ashley', 'Phillips']
# ['Tracey', 'Garza']
# ['Faith', 'Clark']
# ['April', 'Martinez', 'PhD']
# ['Kyle', 'Ruiz', 'II']
# ['Ariana', 'Gallegos']
# ['James', 'Scott']
# ['https://www.lutz-allen.com/Steven_Johnson']
# ['Erin', 'Campbell']
# ['Julie', 'Mathis']
# ['Vanessa', 'Sullivan']
# ['Amanda', 'Andrews']
# ['erogers@example.com']
# ['eburton@example.net']
# ['https://www.wood.biz/Eric_Smith']
# ['https://www.hansen.com/murphyanthony']
# ['http://stewart.net/Deborah_Johns']
# ['Claire', 'Woodward']
# ['Martha', 'Brown']
# ['Margaret', 'Taylor']
# ['Henry', 'Smith']
# ['Jenna', 'Austin']
# ['Jason', 'Phillips']
# ['Rebecca', 'Dawson']
# ['David', 'Ayers']
# ['Sharon', 'Morgan']
# ['Rebecca', 'Wilson']
# ['Michelle', 'Gibbs']
# ['Nicole', 'Rodriguez']
# ['Michael', 'Simmons']
# ['Sarah', 'Bentley']
# ['Nancy', 'Bailey']
# ['Amber', 'Townsend']
# ['Michael', 'Smith']
# ['James', 'Davis']
# ['Andrew', 'Bennett']
# ['Kimberly', 'Burns']
# ['Jennifer', 'Johnson']
# ['Alexandria', 'Meyer']
# ['Melissa', 'Strickland']
# ['Martha', 'Gonzales']
# ['http://wendygarcia.com']
# ['Timothy', 'Yang']
# ['Jennifer', 'Smith']
# ['Beverly', 'Fisher']
# ['William', 'Taylor']
# ['Nicole', 'Conner']
# ['Daniel', 'Thompson']
# ['James', 'Olson']
# ['John', 'Santos']
# ['Noah', 'Day']
# ['Darlene', 'Davis']
# ['Brian', 'Berry']
# ['Megan', 'Adams']
# ['Anthony', 'Hall']
# ['Kelly', 'Burns']
# ['Gregory', 'Smith']
# ['Susan', 'Rose']
# ['Susan', 'Mcpherson']
# ['Jessica', 'Cook']
# ['Connie', 'Odonnell']
# ['Matthew', 'Moore', 'II']
# ['Tracey', 'Collier']
# ['Joseph', 'Cantu']
# ['William', 'Jones']
# ['Shawn', 'Esparza']
# ['Gregory', 'Sheppard']
# ['Oscar', 'Trevino']
# ['Jean', 'Espinoza']
# ['Guy', 'Rodriguez']
# ['Melissa', 'Francis']
# ['Lynn', 'Saunders']
# ['Steven', 'Fletcher']
# ['Kelli', 'Kelly']
# ['Carolyn', 'Cooper']
# ['Jason', 'Meyer']
# ['Christine', 'Holder']
# ['Cody', 'Erickson']
# ['Cathy', 'Griffin']
# ['James', 'Flynn']
# ['Amy', 'Myers']
# ['Holly', 'Hodges']
# ['Kyle', 'Moore']
# ['Amanda', 'Mayer']
# ['Brendan', 'Elliott']
# ['William', 'Bradley']
# ['shermanheather@example.com']
# ['Jasmine', 'Smith']
# ['markdavis@example.net']
# ['Joshua', 'Hughes']
# ['Monica', 'Carter']
# ['Ashley', 'Collins']
# ['Andrea', 'Higgins']
# ['Haley', 'Mckenzie']
# ['Shirley', 'Floyd']
# ['Steven', 'Jones']
# ['David', 'Porter']
# ['Mr.', 'Gregory', 'Johnson']
# ['Paul', 'Cline']
# ['David', 'Davis']
# ['Paula', 'Oconnor']
# ['Robert', 'Meyers']
# ['Thomas', 'Rice']
# ['David', 'Phillips']
# ['Blake', 'Sanchez']
# ['Katherine', 'Perry']
# ['Angel', 'Smith']
# ['Morgan', 'Perry']
# ['Sheri', 'Smith']
# ['Brandon', 'Johnson']
# ['9419259278']
# ['(226)450-3704x7340']
# ['488.660.0235']
# ['+1-252-941-2715x5529']
# ['orrstephanie@example.com']
# ['Mitchell', 'Smith']
# ['http://kara43.com']
# ['Norman', 'Guzman']
# ['Robin', 'Davis']
# ['William', 'Jones']
# ['Richard', 'Johnson']
# ['Paige', 'Bowers']
# ['Ashley', 'Beck']
# ['Derek', 'Brooks']
# ['williamsandrea@example.net']
# ['Matthew', 'Wilson']
# ['wcunningham@example.net']
# ['Frank', 'Roy']
# ['Joshua', 'Williams']
# ['robert36']
# ['tracy09']
# ['Penny', 'Bell']
# ['morajoshua@example.net']
# ['Kevin', 'Palmer']
# ['William', 'Li']
# ['Stephen', 'Evans', 'DDS']
# ['Joanna', 'Wilson']
# ['Kimberly', 'Nguyen']
# ['Henry', 'Boyd']
# ['Christopher', 'Anderson']
# ['Michael', 'Brown']
# ['http://muellermary.com']
# ['Patricia', 'Beasley']
# ['Michael', 'Ward']
# ['Richard', 'Thomas']
# ['Lindsey', 'Black']
# ['Julie', 'Moreno']
# ['David', 'Price']
# ['Amy', 'Nixon']
# ['Cindy', 'Rice']
# ['Drew', 'Vasquez']
# ['Mr.', 'Bruce', 'Brown']
# ['Bradley', 'Franklin']
# ['John', 'Orr']
# ['Stephen', 'Campbell']
# ['Ryan', 'Hickman']
# ['Cory', 'Johnson']
# ['Sarah', 'Lane']
# ['Jacob', 'Howard']
# ['220257038697']
# ['Sarah', 'Nelson']
# ['770949001617']
# ['Michael', 'Richardson']
# ['Raymond', 'Smith']
# ['Jennifer', 'Stephens']
# ['Brent', 'Moran', 'PhD']
# ['Jesse', 'Campbell']
# ['Melissa', 'Jacobs']
# ['Elizabeth', 'Harris']
# ['vazquezmatthew@example.org']
# ['9375882497']
# ['+1-712-453-8796x945']
# ['+1-323-602-1613x80385']
# ['855-807-6596x39201']
# ['James', 'Hamilton']
# ['Daniel', 'Petersen']
# ['Kelly', 'Adams']
# ['Noah', 'Madden']
# ['Denise', 'Chen']
# ['Bruce', 'Patterson']
# ['Kelli', 'Marshall']
# ['Douglas', 'Watson']
# ['Brittany', 'Garcia']
# ['Amanda', 'Carroll']
# ['Cindy', 'Green']
# ['Linda', 'Decker']
# ['Dillon', 'Ryan']
# ['Mark', 'Lopez']
# ['Jermaine', 'Wilkins']
# ['710325396553']
# ['Caroline', 'Phelps']
# ['Alison', 'Miller']
# ['250150906377']
# ['699511405383']
# ['Patricia', 'White']
# ['Samuel', 'Johnson']
# ['Teresa', 'Henry']
# ['Kathryn', 'Smith', 'DVM']
# ['Patrick', 'Stewart']
# ['Patrick', 'Hunt']
# ['Heidi', 'Armstrong']
# ['Heather', 'Larson']
# ['883323839350']
# ['Andrea', 'Ortega']
# ['864613219011']
# ['Lynn', 'Walker']
# ['590963275036']
# ['Amber', 'Brown']
# ['Sarah', 'Smith']
# ['Peter', 'Klein']
# ['Tammy', 'Turner']
# ['517047597704']
# ['435375312247']
# ['Christopher', 'Espinoza']
# ['Courtney', 'Garcia']
# ['Donna', 'Diaz']
# ['Matthew', 'Stewart']
# ['Jerry', 'Hamilton']
# ['113587494755']
# ['https://www.white.info/dmoss']
# ['April', 'Reyes']
# ['Misty', 'Garcia']
# ['Stephen', 'Johnson']
# ['William', 'Fitzgerald']
# ['Jessica', 'Moore']
# ['William', 'Adams']
# ['Jordan', 'Hebert']
# ['Lindsey', 'Shepherd']
# ['Tonya', 'Carson']
# ['Edward', 'King']
# ['Janice', 'Smith']
# ['Christian', 'Martinez']
# ['Angela', 'Andrade']
# ['Thomas', 'Lynn']
# ['Paul', 'Cooper']
# ['Ashley', 'Jackson']
# ['Nathan', 'Shah']
# ['Cathy', 'Hoover']
# ['Lauren', 'Austin']
# ['Jerry', 'Wood']
# ['Elizabeth', 'Juarez']
# ['Devin', 'Ramos', 'PhD']
# ['April', 'Hall']
# ['Jacqueline', 'Hayes']
# ['mejiaamber@example.org']
# ['Melanie', 'Martin']
# ['Scott', 'Evans']
# ['Tyler', 'Holmes']
# ['Charles', 'Dixon']
# ['Dale', 'Baker']
# ['Karen', 'Black']
# ['Trevor', 'Giles']
# ['Sara', 'Perez']
# ['Darren', 'Allen']
# ['Ariana', 'Armstrong']
# ['Joseph', 'Hernandez']
# ['John', 'Reynolds']
# ['Jennifer', 'Chavez']
# ['Donna', 'Mack']
# ['gbrooks@example.org']
# ['Samantha', 'Ho']
# ['Erin', 'Hickman']
# ['Catherine', 'Rodriguez']
# ['Kayla', 'English', 'MD']
# ['James', 'Vang']
# ['Katie', 'Anthony']
# ['Dustin', 'Mcdonald']
# ['Jon', 'Turner']
# ['Dennis', 'Smith']
# ['David', 'Snyder']
# ['Andrea', 'Tanner']
# ['Wendy', 'Ball']
# ['Michael', 'Jones']
# ['Christopher', 'Case']
# ['Phillip', 'Jackson']
# ['Andrew', 'Park']
# ['Julie', 'Thompson']
# ['Adam', 'Guzman']
# ['Debra', 'Davis']
# ['740513510239']
# ['118503250798']
# ['Laura', 'Walker']
# ['David', 'Mason']
# ['827942294760']
# ['295406627328']
# ['Todd', 'Bradford']
# ['Karen', 'Aguilar']
# ['Jennifer', 'Meyers']
# ['995292023095']
# ['974253516532']
# ['Eric', 'Newton']
# ['Chad', 'Fernandez']
# ['660516321991']
# ['942322974675']
# ['Scott', 'Dickson']
# ['William', 'Garcia']
# ['Jerry', 'White']
# ['Linda', 'Rodriguez']
# ['James', 'Maxwell']
# ['Jasmine', 'Rice']
# ['429682727242']
# ['William', 'Sanders']
# ['http://jackson.biz/ariana44']
# ['Kristine', 'Hobbs']
# ['Nicole', 'Leach']
# ['Jessica', 'Ortega']
# ['xburke']
# ['Brian', 'Gonzalez', 'Jr.']
# ['Jon', 'Callahan']
# ['Nicholas', 'Lewis']
# ['Rachel', 'Bullock']
# ['Brandon', 'Anderson']
# ['Cheryl', 'Johnson']
# ['Rachel', 'Molina']
# ['Brian', 'Wright']
# ['Jeremy', 'Fisher']
# ['Ryan', 'Garcia']
# ['Stephen', 'Meyers']
# ['Frank', 'Henson']
# ['290682106205']
# ['600048875246']
# ['Timothy', 'George']
# ['Patrick', 'Pearson']
# ['Kayla', 'Wong']
# ['Eddie', 'Vazquez']
# ['Mary', 'Howard']
# ['Cynthia', 'Martinez']
# ['Ricardo', 'Flores', 'DVM']
# ['Antonio', 'Kim']
# ['Julie', 'Mcintyre']
# ['Kimberly', 'Oliver']
# ['Daniel', 'Ho']
# ['Jennifer', 'Miller']
# ['Lori', 'Schneider']
# ['Danny', 'Yates']
# ['http://vang-thomas.com/Sherri_Waller']
# ['https://www.baxter.com/conradmatthew']
# ['Tyler', 'Butler']
# ['Peter', 'Carr']
# ['Chad', 'Monroe']
# ['James', 'Suarez']
# ['Rodney', 'Rodriguez']
# ['http://smith.info/todd12']
# ['Jamie', 'Mitchell']
# ['William', 'Davis']
# ['Lee', 'Weber']
# ['Rachel', 'Taylor']
# ['Bryan', 'Smith']
# ['Alexis', 'Watkins']
# ['Jordan', 'Barrett']
# ['Morgan', 'Garcia']
# ['Emily', 'Washington']
# ['Gary', 'Schultz']
# ['Ann', 'Carson']
# ['Lisa', 'Ferguson']
# ['Arthur', 'Stephens']
# ['James', 'Brown']
# ['William', 'Kirby']
# ['Mike', 'Brown']
# ['Lawrence', 'Lopez']
# ['Sarah', 'Wiley']
# ['Jacqueline', 'Walker', 'MD']
# ['Stephanie', 'Sanders']
# ['Tony', 'Clark']
# ['Sarah', 'Bullock']
# ['https://www.smith.net/thorntondebra']
# ['Laura', 'James']
# ['Bonnie', 'Suarez']
# ['kristin13@example.net']
# ['688.733.4092x653']
# ['001-861-398-5044x71042']
# ['542-760-8678']
# ['279.245.8739']
# ['Jessica', 'Galvan']
# ['kanderson@example.org']
# ['282-630-0265x863']
# ['273-793-7300']
# ['(255)403-1672']
# ['001-296-471-8019']
# ['Gerald', 'Gutierrez']
# ['leslie93@example.org']
# ['+1-973-395-3785x00128']
# ['595.530.1671']
# ['304.469.0830']
# ['382-644-7311']
# ['https://cook.com/Christine_Bruce']
# ['https://www.robinson-davidson.com/josephjordan']
# ['Rebecca', 'Garcia']
# ['Terry', 'Lane']
# ['Mr.', 'Christopher', 'Sanders']
# ['Amanda', 'Harrison']
# ['Mr.', 'Alejandro', 'Kelley']
# ['Anna', 'Clark']
# ['Joseph', 'Dyer']
# ['Gregory', 'Wall']
# ['Laurie', 'Cummings']
# ['Ryan', 'Taylor']
# ['Vanessa', 'Long']
# ['Paula', 'Nichols']
# ['Stacie', 'Ashley']
# ['James', 'Miller']
# ['Douglas', 'Rodriguez']
# ['Patricia', 'Patel']
# ['Joseph', 'Lopez']
# ['https://oliver.org/mcopeland']
# ['https://www.davis.org/dwoods']
# ['Edward', 'Sullivan']
# ['Dawn', 'Bell']
# ['Michelle', 'Richards']
# ['Nancy', 'Olson']
# ['847942612477']
# ['786920893594']
# ['Jennifer', 'Harris']
# ['https://www.richard.biz/tateterrance']
# ['Eric', 'King']
# ['Melinda', 'Perez']
# ['Oscar', 'Miller']
# ['Troy', 'Daugherty']
# ['Sue', 'Morris']
# ['Eugene', 'Leblanc']
# ['Shawn', 'Lopez']
# ['Joan', 'Wells']
# ['Mallory', 'Castillo']
# ['732047546198']
# ['Franklin', 'Anderson']
# ['364300403606']
# ['Brian', 'Rogers']
# ['792636568327']
# ['Tara', 'Lambert']
# ['Jennifer', 'Smith']
# ['Stephen', 'Green']
# ['Angela', 'Skinner']
# ['Carlos', 'Thomas']
# ['Anthony', 'Robinson']
# ['susancurry@example.com']
# ['Andrea', 'Harris']
# ['lovemargaret@example.net']
# ['Emily', 'Ryan']
# ['107330862752']
# ['Joseph', 'Valencia']
# ['Bradley', 'Bell']
# ['781213213949']
# ['Leslie', 'Cherry']
# ['Micheal', 'Lewis']
# ['Kevin', 'Calderon']
# ['https://hodges.biz/mccoyhailey']
# ['flong@example.org']
# ['Crystal', 'Young']
# ['Jackie', 'Kaiser']
# ['Jacob', 'Phillips']
# ['Gabriela', 'Donovan']
# ['Kendra', 'Edwards']
# ['Andrew', 'Hayden']
# ['Nicole', 'Brooks']
# ['Melanie', 'Avery']
# ['Jared', 'Davis']
# ['Eric', 'Smith']
# ['David', 'Arias']
# ['Marcus', 'Beasley']
# ['Jennifer', 'Adkins']
# ['Dr.', 'Dillon', 'Shaffer', 'DDS']
# ['Jasmine', 'Meyer']
# ['Kevin', 'Torres']
# ['Christopher', 'Klein']
# ['Andrew', 'Mason', 'DVM']
# ['Misty', 'Novak']
# ['Amanda', 'Ryan']
# ['Julie', 'Steele']
# ['Michaela', 'Beck']
# ['Megan', 'Heath']
# ['Rodney', 'Browning']
# ['Todd', 'Bush']
# ['Thomas', 'Sullivan']
# ['https://www.steele-hines.com/njackson']
# ['Mark', 'Williams']
# ['James', 'Roberts']
# ['http://ibarrabobby.com']
# ['Chad', 'Page']
# ['Diane', 'Burgess']
# ['David', 'Davis']
# ['Henry', 'Shaffer']
# ['William', 'Chavez', 'V']
# ['Jessica', 'Morris']
# ['http://yanderson.com']
# ['Tracy', 'Brown']
# ['http://www.petty.com/brandonmadden']
# ['Courtney', 'Cochran']
# ['Jessica', 'Gutierrez']
# ['Jay', 'Reyes']
# ['Steven', 'Garcia']
# ['Keith', 'Anderson']
# ['Christopher', 'Lee']
# ['phillip05@example.com']
# ['Erin', 'Martinez']
# ['kenneth76@example.net']
# ['Phillip', 'Morgan']
# ['Jenny', 'Nguyen']
# ['Michael', 'Wright']
# ['Stephanie', 'Medina']
# ['Matthew', 'Chapman']
# ['Kelly', 'Mcclure']
# ['Colleen', 'Schmidt']
# ['Julia', 'Cline']
# ['Raymond', 'Parsons']
# ['Nicole', 'Hoffman']
# ['Mrs.', 'Ashley', 'Roth']
# ['Chris', 'Young']
# ['301628871966']
# ['http://www.beasley.com/gutierrezlindsey']
# ['Joseph', 'Livingston']
# ['Sherri', 'Mejia']
# ['Scott', 'White']
# ['Mark', 'Valencia']
# ['Joshua', 'Thompson']
# ['Rita', 'Mitchell']
# ['Cindy', 'Castillo']
# ['Linda', 'Robinson']
# ['Anna', 'Paul']
# ['Rickey', 'Paul']
# ['Rachel', 'Porter']
# ['April', 'Moore']
# ['Laura', 'Perkins']
# ['Dean', 'Rogers']
# ['Aaron', 'Cox']
# ['Cody', 'Jones']
# ['681324990672']
# ['David', 'Williams']
# ['414057138619']
# ['Sabrina', 'Jones']
# ['274792378802']
# ['Nicole', 'Hernandez']
# ['Lisa', 'Cohen']
# ['Tiffany', 'Wilson']
# ['Mr.', 'David', 'Rodriguez']
# ['Tracey', 'Roberts']
# ['Christy', 'Crawford']
# ['Sandra', 'Mcgee']
# ['Craig', 'Johnson']
# ['Brandon', 'Torres']
# ['Janice', 'Terrell']
# ['Wendy', 'Jackson']
# ['Noah', 'Oconnell']
# ['Crystal', 'Quinn']
# ['Bailey', 'Fleming']
# ['rickysmith@example.org']
# ['carolyneaton@example.org']
# ['http://coopercarrie.com']
# ['Melissa', 'Thompson']
# ['erikaclark@example.com']
# ['longlindsay@example.com']
# ['http://robinsonjennifer.com']
# ['Alex', 'Jordan']
# ['Jennifer', 'Mccarthy']
# ['Jonathan', 'Franklin']
# ['Jennifer', 'Jackson']
# ['Jose', 'Hall']
# ['Ryan', 'Bradley']
# ['Mindy', 'Strickland']
# ['http://robertdiaz.com']
# ['Andrew', 'Cruz']
# ['Lynn', 'Vasquez']
# ['Kevin', 'Swanson']
# ['Leslie', 'Roberts']
# ['Bruce', 'Carroll']
# ['Holly', 'Evans']
# ['Veronica', 'Jones']
# ['Herbert', 'Hubbard']
# ['Lindsay', 'Newton']
# ['Michael', 'Pineda']
# ['Richard', 'Hendrix']
# ['Jennifer', 'Baker']
# ['Jillian', 'James']
# ['Gregory', 'Waters']
# ['Stephen', 'French']
# ['Matthew', 'Long']
# ['Grant', 'Carpenter']
# ['Adam', 'Burnett']
# ['James', 'Roberts']
# ['Martha', 'Francis']
# ['Tracey', 'Dudley']
# ['John', 'Marks']
# ['Brenda', 'Fox']
# ['Curtis', 'Barnes']
# ['Robert', 'Yang']
# ['http://www.kim-stephens.com/mark34']
# ['http://fosterkimberly.com']
# ['Karen', 'Sanchez']
# ['Andrew', 'Carrillo']
# ['Robert', 'Lang']
# ['Charles', 'Murray']
# ['https://www.campbell.info/lowezachary']
# ['Laura', 'Munoz']
# ['Michael', 'Mckee']
# ['Matthew', 'Mcguire']
# ['Jessica', 'Spencer']
# ['Gary', 'Callahan']
# ['Crystal', 'Blevins']
# ['Thomas', 'Sloan']
# ['Ashley', 'Mccall']
# ['Emma', 'Carr']
# ['Dylan', 'Russo']
# ['Brianna', 'Martin']
# ['Jill', 'Sexton']
# ['Kenneth', 'Aguilar']
# ['Michelle', 'Rodriguez']
# ['Kathy', 'Turner']
# ['Sean', 'Blackwell']
# ['Jessica', 'Boyd']
# ['Keith', 'Christian']
# ['Melissa', 'Green']
# ['christopher17']
# ['John', 'King']
# ['Phillip', 'Ibarra']
# ['Melinda', 'Velasquez']
# ['Catherine', 'Porter']
# ['Eric', 'Brewer']
# ['Kim', 'Lee']
# ['Jerry', 'Pratt']
# ['Brooke', 'Moore']
# ['Kevin', 'Nguyen']
# ['Theresa', 'Wang']
# ['Tanya', 'Marshall']
# ['Laura', 'Perry']
# ['Monica', 'Munoz']
# ['Christopher', 'Nicholson']
# ['Tyler', 'Harrison']
# ['Michael', 'Haynes']
# ['Jimmy', 'Austin']
# ['Ricky', 'Leblanc']
# ['Heather', 'Fletcher']
# ['Kelly', 'Anderson']
# ['Melissa', 'Mitchell']
# ['John', 'White']
# ['Jessica', 'Carney']
# ['Nicholas', 'House']
# ['Edward', 'Hansen']
# ['Jeffery', 'Cohen']
# ['https://rogers.com/scottcarlos']
# ['Kathleen', 'Russell']
# ['Veronica', 'Moore']
# ['Louis', 'Obrien']
# ['Kristin', 'Horton']
# ['http://vmorrison.com']
# ['Melissa', 'Moore']
# ['John', 'Reeves']
# ['http://www.phelps-camacho.net/vincent81']
# ['Kathleen', 'Stevens']
# ['Adrian', 'Smith']
# ['Nicholas', 'Bradford']
# ['Bonnie', 'Bell']
# ['Jose', 'Cook']
# ['Carol', 'Frye']
# ['Brandon', 'Shaffer']
# ['Jennifer', 'Wallace']
# ['Michael', 'Cook']
# ['Julie', 'Watts']
# ['David', 'Martinez']
# ['Becky', 'Jones']
# ['Mrs.', 'Sandra', 'Adams']
# ['Brian', 'Foster']
# ['Larry', 'Mitchell']
# ['Carrie', 'Reed']
# ['Danielle', 'Bell']
# ['Megan', 'Bennett']
# ['Breanna', 'Hendricks']
# ['Sarah', 'Moore']
# ['Brandy', 'Williams']
# ['Todd', 'Medina']
# ['Christopher', 'Richardson']
# ['Dustin', 'Moore']
# ['Rhonda', 'Mcdowell']
# ['Cynthia', 'Mckinney']
# ['jhanson@example.org']
# ['Kristin', 'Ortiz']
# ['Maria', 'Klein']
# ['Robert', 'Wilson']
# ['Jennifer', 'Rodriguez']
# ['Robin', 'Tran']
# ['Oscar', 'Delgado']
# ['Andrew', 'Tran']
# ['Linda', 'Singh']
# ['Dustin', 'Campbell']
# ['https://chambers-lewis.net/jamesmatthews']
# ['Michael', 'Holland']
# ['Michael', 'Hall']
# ['Robert', 'Campos']
# ['Felicia', 'Garrison']
# ['Thomas', 'Johnson']
# ['Susan', 'Hall']
# ['Kimberly', 'Castillo']
# ['Alan', 'Ellis']
# ['Carl', 'Rodriguez']
# ['http://www.baker-gutierrez.biz/Jordan_Valenzuela']
# ['Kimberly', 'Trevino']
# ['Jill', 'Chung']
# ['Bryan', 'Love']
# ['Corey', 'Glass']
# ['Madison', 'Patrick']
# ['Joshua', 'Rodriguez']
# ['Ricky', 'Mcguire']
# ['Robert', 'Santiago']
# ['Rhonda', 'Hood']
# ['Carolyn', 'Jones']
# ['Bernard', 'Marshall']
# ['Ashley', 'Clark']
# ['Jeremiah', 'Smith']
# ['Barbara', 'Romero']
# ['Aaron', 'Gonzales']
# ['Rachel', 'Watkins']
# ['Teresa', 'Jones']
# ['Elizabeth', 'Frye']
# ['Nancy', 'Little']
# ['Veronica', 'Everett']
# ['crystalcarter@example.net']
# ['hillwalter']
# ['Teresa', 'Frost']
# ['Michelle', 'Baker']
# ['Kathleen', 'Martinez']
# ['Terri', 'Williams']
# ['James', 'Meyer']
# ['Rose', 'Beard']
# ['https://www.day.com/stephanie41']
# ['Tracy', 'Waters']
# ['Alexandria', 'Jackson']
# ['Haley', 'Spencer']
# ['David', 'Robinson']
# ['772970071581']
# ['Michelle', 'Branch']
# ['Robert', 'Cooper']
# ['Jodi', 'Taylor']
# ['Melissa', 'Jackson']
# ['David', 'Griffin']
# ['Matthew', 'Mcdaniel']
# ['Jennifer', 'Greene']
# ['Emily', 'Tucker']
# ['Frederick', 'Jackson']
# ['Walter', 'Lowery']
# ['Shannon', 'Cantu']
# ['Tricia', 'Beard']
# ['Lauren', 'Walter']
# ['Robert', 'Freeman']
# ['Wayne', 'Lewis']
# ['Miguel', 'Mitchell']
# ['Jaime', 'Mcguire']
# ['Denise', 'Young']
# ['Matthew', 'Payne']
# ['146122772413']
# ['Patrick', 'Orr']
# ['Kelly', 'Henson']
# ['Jason', 'Lawrence']
# ['Brian', 'Hodges']
# ['Jared', 'Foster']
# ['Christopher', 'Higgins']
# ['Jacob', 'Hartman']
# ['Monica', 'Cox']
# ['Darryl', 'Wright']
# ['Cynthia', 'Boyd', 'MD']
# ['Albert', 'Becker']
# ['Mark', 'Murphy']
# ['Desiree', 'Lyons']
# ['https://www.smith.org/Timothy_Lyons']
# ['Christopher', 'Hardy']
# ['Lonnie', 'Brown']
# ['Jennifer', 'Swanson']
# ['Holly', 'Chambers']
# ['Michael', 'Ward']
# ['Barbara', 'Wolf', 'MD']
# ['Crystal', 'Higgins']
# ['Monica', 'Cook']
# ['William', 'Brown']
# ['Lisa', 'Clark']
# ['Darius', 'Phelps']
# ['Natalie', 'Davis']
# ['Alexander', 'Miller']
# ['Alyssa', 'Brooks']
# ['Ryan', 'Rhodes']
# ['Lauren', 'Roberts']
# ['Tamara', 'Nielsen']
# ['Dana', 'Rice']
# ['Jenna', 'Russell']
# ['John', 'Miranda']
# ['Leon', 'Jenkins']
# ['http://smith.info/glassdeborah']
# ['Eric', 'Hodges']
# ['mcdanieljohn@example.net']
# ['212624729391']
# ['Kimberly', 'Cohen']
# ['Raymond', 'Guerrero']
# ['stephanie06@example.com']
# ['926981975451']
# ['Amanda', 'Santiago']
# ['Stephanie', 'Moon']
# ['Amy', 'Snyder']
# ['Kevin', 'Parker']
# ['Maria', 'Mcdonald']
# ['Curtis', 'Scott']
# ['Nicholas', 'Martinez']
# ['Veronica', 'Savage']
# ['Michelle', 'Johnson']
# ['Brian', 'Carrillo']
# ['Pamela', 'Hernandez']
# ['John', 'Miller']
# ['Drew', 'Little']
# ['Latoya', 'Jones']
# ['Patrick', 'Cooper']
# ['Aimee', 'Robinson']
# ['Kristopher', 'Johnson']
# ['Matthew', 'Russo']
# ['Michael', 'Smith']
# ['Scott', 'Thompson']
# ['Carrie', 'Schroeder']
# ['Chad', 'Weber']
# ['https://www.phillips.com/bradforddebra']
# ['http://bryan12.com']
# ['https://www.owens-perez.biz/Megan_Jenkins']
# ['Juan', 'Sharp']
# ['Joann', 'Fernandez']
# ['Stephen', 'Webb']
# ['Amanda', 'Navarro']
# ['Megan', 'Bennett']
# ['Paul', 'King']
# ['Jimmy', 'Mccullough']
# ['https://thomas-barnes.biz/mayomonica']
# ['https://www.hatfield-garrett.biz/Alicia_Robertson']
# ['Antonio', 'Wade']
# ['Jill', 'Hall']
# ['William', 'Cameron']
# ['Paul', 'Terry', 'DDS']
# ['Dr.', 'James', 'Parsons']
# ['Donna', 'Nash']
# ['Jeremy', 'Johnston']
# ['Justin', 'Martin']
# ['Emily', 'Dickerson']
# ['Lori', 'Greene']
# ['Sarah', 'Reese']
# ['Jeffrey', 'Carpenter']
# ['Christopher', 'Russell']
# ['Elizabeth', 'Ballard']
# ['Megan', 'Mendez']
# ['Ronald', 'Daniels']
# ['Darryl', 'Calderon']
# ['Jennifer', 'Woodward']
# ['Julie', 'Dougherty']
# ['Terri', 'Hart']
# ['Laura', 'Parrish']
# ['Paige', 'Perry']
# ['Megan', 'Mendoza']
# ['Kelly', 'Webb']
# ['Chris', 'Jarvis']
# ['John', 'Gutierrez']
# ['http://qirwin.com']
# ['Ronald', 'Wise']
# ['Rachel', 'Black']
# ['Sarah', 'Perez']
# ['Shannon', 'Hogan']
# ['Cassandra', 'Dyer']
# ['Natalie', 'Anderson']
# ['Aaron', 'Jones']
# ['Destiny', 'Jenkins']
# ['350945403310']
# ['217983405808']
# ['Matthew', 'Higgins']
# ['https://johnson.org/katiewebb']
# ['https://williams.com/Carrie_Castillo']
# ['https://baker.net/christopher00']
# ['Ralph', 'Turner']
# ['Theresa', 'Bell']
# ['William', 'Henderson']
# ['William', 'Conner']
# ['Christopher', 'Bauer']
# ['James', 'Thornton']
# ['Tara', 'Huerta']
# ['Laurie', 'Flores', 'DVM']
# ['Wayne', 'Smith']
# ['David', 'Smith']
# ['432252904092']
# ['313172715722']
# ['Daniel', 'Oliver']
# ['Allen', 'Washington']
# ['Russell', 'Medina']
# ['Brent', 'Warren']
# ['Lisa', 'Ramirez']
# ['Joseph', 'Hamilton']
# ['Brittney', 'Clark']
# ['Makayla', 'Watson']
# ['Jennifer', 'Garcia']
# ['Teresa', 'Richardson']
# ['260669497849']
# ['676382887553']
# ['Gary', 'Cannon']
# ['Krista', 'Ayala']
# ['http://www.coffey.com/Stephanie_Bennett']
# ['Jennifer', 'Schmidt']
# ['Sandra', 'Henderson']
# ['Sally', 'Garcia']
# ['Lindsey', 'Cruz']
# ['Tina', 'Kennedy']
# ['Christopher', 'Ellis']
# ['Mark', 'Norman']
# ['http://cochran-hull.com/leahguzman']
# ['Pamela', 'Fox']
# ['Kimberly', 'Kramer']
# ['Ashley', 'Cuevas']
# ['Shaun', 'Silva']
# ['Holly', 'Cordova']
# ['Janet', 'Santos']
# ['Samantha', 'Valentine']
# ['Annette', 'Thomas']
# ['Brandon', 'Lucas']
# ['127548810105']
# ['Scott', 'Holden']
# ['903365222071']
# ['Jennifer', 'Mclaughlin']
# ['346046287782']
# ['Eileen', 'Shaw']
# ['382086227620']
# ['Dennis', 'Stevens']
# ['543549226196']
# ['Tiffany', 'Banks']
# ['Michelle', 'Guerrero']
# ['Michael', 'Jones']
# ['http://whitebrian.com']
# ['Roy', 'Nash']
# ['Rachel', 'Paul']
# ['Lucas', 'Davis']
# ['Danielle', 'Mason']
# [['505', 'Berry', 'Pike', 'Suite', '571\nEast', 'Paul,', 'FM', '66884']]
# [['6387', 'Williams', 'Crescent', 'Suite', '409\nSouth', 'Katherine,', 'VT', '81991']]
# [['96839', 'Meyers', 'Spring\nMariahborough,', 'DE', '74106']]
# [['81376', 'Foster', 'Stravenue\nDoyleborough,', 'VT', '65286']]
# [['411', 'Powell', 'Drives', 'Apt.', '490\nLongberg,', 'TN', '58523']]
# [['186', 'Davis', 'Point\nWatsonton,', 'IA', '98144']]
# [['68956', 'Alexander', 'Ramp\nNicolestad,', 'MA', '29685']]
# [['2551', 'Schaefer', 'Flats', 'Suite', '723\nNew', 'Mariaborough,', 'GA', '64293']]
# [['9783', 'Gonzalez', 'Way', 'Suite', '428\nJonesville,', 'VA', '69266']]
# [['830', 'Rebecca', 'Tunnel', 'Suite', '417\nSouth', 'Donaldport,', 'NE', '44147']]
# [['7695', 'Vang', 'Burgs\nBriantown,', 'MD', '38495']]
# ['363.331.9282']
# ['http://jperez.com']
# ['Sharon', 'Woodard']
# ['Matthew', 'Lang']
# ['Tammy', 'Dunn']
# ['Kathryn', 'Thomas']
# ['https://martinez-watson.biz/Pamela_Park']
# ['https://white.com/debbiecarter']
# ['http://heatherlittle.com']
# ['Ashley', 'Morris']
# ['Jordan', 'Compton']
# ['Joanna', 'Fernandez']
# ['Justin', 'Rich']
# ['Karen', 'Kelley']
# ['David', 'Perkins']
# ['Anne', 'Rojas']
# ['Timothy', 'Small']
# ['Kristen', 'Martinez']
# ['Richard', 'Butler']
# ['Cynthia', 'Chavez']
# ['Angela', 'Zimmerman']
# ['Kelly', 'Marquez']
# ['Kathleen', 'Sharp']
# ['Andrew', 'Ford']
# ['http://amandagibbs.com']
# ['Javier', 'Price']
# ['Anthony', 'Roman']
# ['Kelly', 'Ruiz']
# ['Mrs.', 'Susan', 'Torres']
# ['http://lowerydennis.com']
# ['Patricia', 'Johnson']
# ['Crystal', 'Knight']
# ['Jennifer', 'Whitehead']
# ['Lisa', 'Torres']
# ['Jennifer', 'Thomas']
# ['Cory', 'Trevino']
# ['Gloria', 'Barnes']
# ['Brooke', 'Moore']
# ['Carolyn', 'Banks']
# ['Lisa', 'Moreno']
# ['Courtney', 'Douglas']
# ['Richard', 'Andrews']
# ['Peter', 'Cook']
# ['Jennifer', 'White']
# ['Jacqueline', 'Serrano']
# ['Wyatt', 'Miller']
# ['Wendy', 'Rose', 'DVM']
# ['Jose', 'Davis']
# ['Michelle', 'Johnston']
# ['Michelle', 'Wright']
# ['Tracey', 'Bryant']
# ['James', 'Simmons']
# ['Kimberly', 'Cortez']
# ['Cindy', 'King']
# ['Joseph', 'Padilla']
# ['Amanda', 'King']
# ['James', 'Tucker']
# ['Nicole', 'Allen']
# ['Steven', 'Chung']
# ['Andrew', 'Griffin']
# ['Antonio', 'Terry']
# ['http://dbarajas.com']
# ['http://www.vaughan-young.com/William_Sandoval']
# ['Emily', 'Lee']
# ['Michael', 'Pena']
# ['Kimberly', 'Stark']
# ['887863739427']
# ['Angela', 'Russell']
# ['Debra', 'Boyd', 'DVM']
# ['Gary', 'Wilson']
# ['James', 'Carlson']
# ['108200011997']
# ['Juan', 'Wood']
# ['William', 'Chen']
# ['Nicholas', 'Carter']
# ['Rita', 'Williams']
# ['Angela', 'Brown']
# ['Kevin', 'Ponce']
# ['Sheila', 'Phillips']
# ['Christopher', 'Wilson']
# ['Glenn', 'Morales']
# ['http://hoodmatthew.com']
# ['http://higginsterry.com']
# ['https://vargas.com/Michelle_Wilkinson']
# ['http://www.martin.com/ramirezlauren']
# ['https://gonzalez-james.com/Brenda_Marquez']
# ['http://joanna35.com']
# ['https://wolf.com/travishardy']
# ['Michelle', 'Savage']
# ['Thomas', 'Waters']
# ['Cody', 'Deleon']
# ['Jennifer', 'Edwards']
# ['Teresa', 'Fuller']
# ['Jose', 'Richards']
# ['Elizabeth', 'Harris']
# ['Steven', 'Gregory']
# ['Brandy', 'Robinson']
# ['Jim', 'Mcbride']
# ['Nancy', 'Lloyd']
# ['http://www.smith.com/steven10']
# ['Douglas', 'Mitchell']
# ['Christian', 'Parker']
# ['Cynthia', 'Atkinson']
# ['Richard', 'Walls']
# ['Ryan', 'Reese']
# ['Terrence', 'Russo']
# ['Edward', 'Perez']
# ['Michelle', 'Mitchell']
# ['Megan', 'Davis']
# ['Katherine', 'Brown']
# ['Kerri', 'Hanson']
# ['Amy', 'Garcia']
# ['Rachel', 'Duran']
# ['Taylor', 'Lewis']
# ['Thomas', 'Mendez']
# ['Jessica', 'Weber']
# ['Bonnie', 'Contreras']
# ['Kimberly', 'Cook']
# ['Matthew', 'Snyder']
# ['qpage@example.net']
# ['https://www.mcfarland.net/jjackson']
# ['kennedyryan@example.net']
# ['http://www.collier.com/ramospreston']
# ['Daniel', 'Johnson']
# ['Kerry', 'Collins']
# ['Natasha', 'Smith']
# ['Sandra', 'Johnson']
# ['Daniel', 'Lee']
# ['Douglas', 'Merritt']
# ['Eric', 'Robinson']
# ['http://michaelgomez.com']
# ['John', 'Ballard']
# ['Marie', 'Owens']
# ['Kathryn', 'Mullins']
# ['Alyssa', 'Green']
# ['Carl', 'Jones']
# ['Brett', 'Mcneil']
# ['Casey', 'Cruz']
# ['Patricia', 'Smith']
# ['Krystal', 'Alexander']
# ['Jessica', 'Cole']
# ['Jill', 'Lee']
# ['Christopher', 'Miller']
# ['Madison', 'Johnson']
# ['Scott', 'Lee']
# ['http://www.hunt.net/dthomas']
# ['Steven', 'Roman']
# ['Dr.', 'Kimberly', 'Leon']
# ['Caleb', 'Walsh']
# ['David', 'Johnson']
# ['James', 'Scott']
# ['Joshua', 'Sellers']
# ['Taylor', 'Nguyen']
# ['Pamela', 'Williams']
# ['Shannon', 'Martinez']
# ['Nichole', 'Morgan']
# ['Jeffrey', 'Mason']
# ['Paul', 'Irwin']
# ['Melissa', 'Davis']
# ['Michael', 'Underwood']
# ['denisemills@example.net']
# ['hammondfelicia@example.net']
# ['Peter', 'Marks']
# ['Veronica', 'Miller']
# ['Karla', 'Andrews']
# ['Edward', 'Hughes']
# ['http://www.jennings.biz/Suzanne_Patrick']
# ['Damon', 'Gutierrez']
# ['Chelsea', 'Burton']
# ['John', 'George']
# ['Jeremiah', 'Carter', 'Jr.']
# ['Amanda', 'Padilla']
# ['Jessica', 'Howard']
# ['Andrea', 'Tate']
# ['Mr.', 'Peter', 'Alexander']
# ['Natalie', 'Bolton']
# ['Randy', 'Foster']
# ['Charles', 'Myers']
# ['http://www.garcia.com/Morgan_Wilson']
# ['https://watson-brown.com/kriley']
# ['Kelly', 'Scott']
# [['4211', 'Jones', 'Cliffs', 'Apt.', '940\nCarlsonmouth,', 'AL', '13105']]
# [['649', 'Burke', 'Mountains\nNorth', 'Nicolemouth,', 'ID', '46362']]
# [['05790', 'Elizabeth', 'Forest\nLake', 'Billyfort,', 'WA', '97894']]
# [['693', 'Hayley', 'Walk\nVincentport,', 'NE', '93960']]
# [['057', 'Beck', 'Crest\nEast', 'Linda,', 'WY', '28702']]
# [['92748', 'Bruce', 'Tunnel', 'Apt.', '812\nDanielhaven,', 'MN', '24592']]
# [['501', 'Foster', 'Squares', 'Apt.', '221\nWhitefurt,', 'NY', '08113']]
# [['1807', 'Campbell', 'Branch\nNguyenside,', 'MI', '41951']]
# [['729', 'Eric', 'Fork\nSouth', 'David,', 'TX', '91056']]
# [['950', 'Meyer', 'Terrace\nCollinstown,', 'AZ', '61713']]
# [['79044', 'Brooks', 'Manors\nLake', 'Brittany,', 'AK', '56967']]
# ['Cynthia', 'Neal']
# ['Daniel', 'Spencer']
# ['Eric', 'Riddle']
# ['Sean', 'Beck', 'DDS']
# ['Mr.', 'Eric', 'Murray', 'V']
# ['Sara', 'Cox']
# ['Nancy', 'Davis']
# ['Jacob', 'Smith']
# ['Joshua', 'Morgan']
# ['Jonathan', 'Fowler']
# ['Sheila', 'Flores']
# ['Sharon', 'Ali', 'MD']
# ['Stephanie', 'Dunn']
# ['Brian', 'Nelson']
# ['Gina', 'Stewart']
# ['Laura', 'Lucas']
# ['Megan', 'Lambert']
# ['Robert', 'Turner']
# ['Deborah', 'Hunter']
# ['Sara', 'Burgess']
# ['Julia', 'Lopez']
# ['Justin', 'Greene']
# ['John', 'Perez']
# ['David', 'Jones']
# ['Jesse', 'Cruz']
# ['Sara', 'Hubbard']
# ['James', 'Hamilton']
# ['Jacob', 'Smith']
# ['Marc', 'Thompson']
# ['John', 'Medina']
# ['Marcus', 'Ramos']
# ['Crystal', 'Holmes']
# ['Edgar', 'Williams']
# ['Thomas', 'Kelley']
# ['Christopher', 'Cordova']
# ['Tanya', 'Chaney']
# ['Michael', 'Holmes']
# ['Randy', 'Martin']
# ['Alexis', 'Solis']
# ['David', 'Alexander']
# ['Jennifer', 'Johnson']
# ['Jack', 'Harper']
# ['Wendy', 'Powell']
# ['Joanna', 'Dean']
# ['Sonya', 'Huff']
# ['Ashley', 'Gray']
# ['Teresa', 'Huff']
# ['Jennifer', 'Morrison']
# ['Stephanie', 'Thornton']
# ['Brenda', 'Herrera']
# ['Emily', 'Cohen']
# ['Victoria', 'Cohen']
# ['Cody', 'Barnes']
# ['Jesse', 'Perkins']
# ['Selena', 'Thomas']
# ['Randy', 'Sanchez']
# ['Jonathan', 'Carson']
# ['Angelica', 'Rodriguez']
# ['Jennifer', 'Jackson']
# ['Jennifer', 'Carter']
# ['Theresa', 'Castillo']
# ['Nathan', 'Rivera']
# ['Laurie', 'Berg']
# ['Michael', 'Mason']
# ['Alexander', 'Perez']
# ['Shirley', 'Rhodes']
# ['Dr.', 'Roger', 'Brown', 'DDS']
# ['Anthony', 'Robinson']
# ['Regina', 'Andrade']
# ['Matthew', 'Wright']
# ['Martha', 'Orozco']
# ['Richard', 'Boyer']
# ['Monica', 'Riggs']
# ['Ryan', 'Moore']
# ['https://www.hutchinson.com/Kaitlin_Cummings']
# ['Shane', 'Douglas']
# ['Heather', 'Suarez']
# ['dtaylor@example.net']
# ['Breanna', 'Jones']
# ['Tiffany', 'Gray']
# ['Jared', 'Miller']
# ['Ricardo', 'Young']
# ['https://www.hays.biz/shannondana']
# ['Richard', 'Ferguson']
# ['Cameron', 'Romero']
# ['414649961575']
# ['Michael', 'House']
# ['Sierra', 'Blackwell']
# ['109180941199']
# ['Joshua', 'James']
# ['861138245706']
# ['Jennifer', 'Davidson']
# ['529775162974']
# ['Timothy', 'Martinez']
# ['Corey', 'Dickerson']
# ['Carrie', 'Short']
# ['Derek', 'Rivera']
# ['jeffrey02@example.net']
# ['Adam', 'Young']
# ['Stephanie', 'Davis']
# ['sarahward@example.com']
# ['Nicholas', 'Johnson']
# ['Kevin', 'Taylor']
# ['ishepherd@example.net']
# ['Richard', 'Owens']
# ['Trevor', 'Vazquez']
# ['Lori', 'Johnson']
# ['David', 'Mcclure']
# ['Mary', 'Perry']
# ['Jeffrey', 'Castillo']
# ['Christopher', 'Roberts']
# ['http://www.torres.net/Joseph_Tran']
# ['http://scott32.com']
# ['Steven', 'Bonilla']
# ['https://stephens.com/chandlerpaul']
# ['Mr.', 'Robert', 'Stephens']
# ['Adam', 'Ortiz']
# ['Jessica', 'Rose']
# ['Paul', 'Hodge']
# ['John', 'Martin']
# ['Amber', 'Anderson']
# ['Steven', 'Martinez']
# ['Destiny', 'Knox']
# ['Donald', 'Collins']
# ['Tiffany', 'Perry']
# ['Duane', 'Chaney']
# ['Lauren', 'Castillo']
# ['http://stephaniewaller.com']
# ['http://johnstonchristine.com']
# ['https://www.sharp-bradford.net/adamharris']
# ['http://www.richardson-anthony.com/tbryant']
# ['Stephen', 'Alexander']
# ['Joshua', 'Curry']
# ['Scott', 'Cisneros']
# ['133125959163']
# ['Jared', 'Alvarado']
# ['708294161004']
# ['Leonard', 'Barajas']
# ['James', 'Ali']
# ['379342617384']
# ['Rebecca', 'Forbes']
# ['693352923970']
# ['Timothy', 'Johnson']
# ['Jonathan', 'Hebert']
# ['Gary', 'Brewer']
# ['Brad', 'Holland']
# ['Jessica', 'Davis']
# ['Andres', 'Perez']
# ['Justin', 'Donaldson']
# ['Thomas', 'Davis']
# ['Jonathan', 'Jones']
# ['Tyler', 'Mccoy']
# ['William', 'Snyder']
# ['Joseph', 'Gomez', 'DDS']
# ['https://www.curry.info/atorres']
# ['http://lloyd.com/howellashley']
# ['Nathan', 'Huynh']
# ['Brianna', 'Cox']
# ['Curtis', 'Haynes']
# ['Nicole', 'Ross']
# ['Steven', 'Hardy']
# ['William', 'Jensen']
# ['Kathryn', 'Collins']
# ['Danielle', 'Anderson']
# ['Paul', 'Jacobs']
# ['Trevor', 'Frost']
# ['Anita', 'Good']
# ['Alex', 'Love']
# ['Dr.', 'Patricia', 'Gonzalez', 'MD']
# ['James', 'Moore']
# ['Edward', 'Peterson']
# ['Mrs.', 'Mary', 'Martin']
# ['Michelle', 'Reid']
# ['Thomas', 'Dixon']
# ['Misty', 'Robinson']
# ['Ellen', 'Stephens']
# ['Jennifer', 'Little']
# ['Gloria', 'Dunn']
# ['Mary', 'Coleman']
# ['Nicholas', 'Smith', 'DDS']
# ['http://petersontracy.com']
# ['http://zacharyedwards.com']
# ['Charles', 'Thompson']
# ['http://www.poole.com/Katherine_Jensen']
# ['Robert', 'George']
# ['889575455655']
# ['Rodney', 'Hancock']
# ['Matthew', 'Cooper']
# ['288361826996']
# ['Luis', 'Parker']
# ['Donna', 'Lewis']
# ['Stephanie', 'Gibson']
# ['472971487011']
# ['Kelly', 'Smith']
# ['William', 'Hurst']
# ['Dorothy', 'Moore']
# ['https://www.holmes.net/atkinswilliam']
# ['http://stephaniejohnson.com']
# ['Ms.', 'Heather', 'Jones']
# ['Thomas', 'Baker']
# ['Sheryl', 'Allison']
# ['Erica', 'Cole']
# ['Thomas', 'Evans']
# ['David', 'Fischer']
# ['Ryan', 'Gray']
# ['Brian', 'Russell']
# ['Krista', 'Castillo']
# ['Xavier', 'Williams']
# ['Katie', 'Stewart']
# ['Alexander', 'Smith']
# ['Frank', 'Lyons']
# ['Lori', 'Sawyer']
# ['Donna', 'Simmons']
# ['Megan', 'Pierce']
# ['Andrew', 'Martinez']
# ['Pamela', 'Thompson']
# ['Kent', 'Carlson']
# ['Nicholas', 'Guerra']
# ['http://villanuevadaniel.com']
# ['Regina', 'Hutchinson']
# ['James', 'Arnold']
# ['Samuel', 'Rivera']
# ['Beth', 'Thompson']
# ['Megan', 'Kelley']
# ['Isaac', 'Sexton']
# ['Angela', 'Lewis']
# ['Courtney', 'Dominguez']
# ['Rachel', 'Barnett']
# ['Brian', 'Cortez']
# ['Gary', 'Stephenson']
# ['Virginia', 'Holland']
# ['Mr.', 'Kyle', 'Flynn']
# ['Sandra', 'Johnson']
# ['Matthew', 'Dunn']
# ['Paul', 'Keith']
# ['Angela', 'English']
# ['Tara', 'Zhang']
# ['Nicholas', 'Alvarado']
# ['Michelle', 'Carter']
# ['yboyd@example.net']
# ['Caitlyn', 'Waters']
# ['Allen', 'Mckee']
# ['Alexandra', 'Flores']
# ['Joe', 'Berger']
# ['Heather', 'Evans']
# ['Amanda', 'Barnett']
# ['William', 'Fields']
# ['Micheal', 'Lane']
# ['Connor', 'Morris']
# ['Rebecca', 'Lee']
# ['Evelyn', 'Bailey']
# ['Christine', 'Lewis']
# ['Melanie', 'Weeks']
# ['Patricia', 'Durham']
# ['https://dennis-young.com/mscott']
# ['https://williams.com/Nancy_Hatfield']
# ['http://tracialvarez.com']
# ['http://janet64.com']
# ['https://rhodes-lynn.org/browncameron']
# ['http://www.frederick.com/Courtney_Morris']
# ['http://crawford-miller.com/Sara_Conley']
# ['http://amy40.com']
# ['Nicholas', 'Reid']
# ['Anthony', 'Murray']
# ['Samantha', 'Mckay']
# ['Kari', 'Jennings']
# ['Stephanie', 'Dominguez']
# ['Raven', 'Mcconnell']
# ['Christine', 'Williams']
# ['Robert', 'Nelson']
# ['Philip', 'Anderson']
# ['Crystal', 'Taylor']
# ['John', 'Cooke']
# ['Allen', 'Watson']
# ['Keith', 'Ferguson']
# ['Stephanie', 'Evans']
# ['Dawn', 'Davis']
# ['Lindsey', 'Smith']
# ['Sheena', 'Dunn']
# ['Mr.', 'Stephen', 'Gardner']
# ['Jose', 'Rocha']
# ['Robert', 'Dorsey']
# ['Brandon', 'Price']
# ['Monica', 'Salinas']
# ['Anna', 'Marshall']
# ['James', 'Lindsey']
# ['Daniel', 'Willis']
# ['Evan', 'Williams', 'DDS']
# ['Jordan', 'Burton']
# ['Jason', 'Wilson', 'DVM']
# ['Nancy', 'Downs']
# ['Jay', 'Richards']
# ['Willie', 'Rodriguez']
# ['David', 'Morales']
# ['Tara', 'Riley']
# ['Mark', 'Smith']
# ['Brittany', 'Hughes']
# ['Courtney', 'Massey']
# ['John', 'Turner']
# ['Rachel', 'Evans']
# ['Benjamin', 'Mann']
# ['Angelica', 'Harris']
# ['John', 'Rice', 'MD']
# ['Megan', 'Butler']
# ['Julie', 'Williams', 'DVM']
# ['Matthew', 'Smith']
# ['Linda', 'Best']
# ['William', 'West']
# ['Keith', 'Davis']
# ['Joshua', 'Williams']
# ['https://bowman-peck.com/Angela_Gilbert']
# ['Ian', 'Barnett']
# ['James', 'Williams']
# ['Phillip', 'Bridges']
# ['Donald', 'Hill']
# ['margaretmiller@example.com']
# ['317873410900']
# ['894753997570']
# ['709789998473']
# ['404727284775']
# ['930695006210']

# %%
augmented_data[160]['tokens']
# Out:
# ['\n\n',
#  'William',
#  'Price',
#  'Newtown',
#  ',',
#  'CT',
#  'USA',
#  '\n\n',
#  'Coursera',
#  ':',
#  'Design',
#  'Thinking',
#  'for',
#  'Innovation',
#  'Jan.',
#  '2',
#  ',',
#  '2017',
#  '\n\n',
#  'Challenge',
#  'and',
#  'Selection',
#  '\n\n',
#  'Coming',
#  'from',
#  'a',
#  'family',
#  'who',
#  'were',
#  'Joseph',
#  'Campbell',
#  'gurus',
#  ',',
#  'members',
#  'of',
#  'AA',
#  'and',
#  ' ',
#  'writers',
#  ',',
#  'Storytelling',
#  'is',
#  'a',
#  'revealing',
#  'tool',
#  'of',
#  'connection',
#  ',',
#  'information',
#  ',',
#  'and',
#  'shared',
#  ' ',
#  'insight']

# %%
len(augmented_data)
# Out:
# 1203

# %%
for doc_id in augmented_data.keys():
    for i, label in enumerate(augmented_data[doc_id]['labels']):
        if 'ID_NUM' in label:
            print(augmented_data[doc_id]['tokens'][i])
# Out:
# 860632713425
# 530670102508
# 530670102508
# 875673967537
# 860632713425
# 557349702179
# 784372734211
# 054176622314
# 674915248960
# 932353568953
# 982645662261
# 409046248321
# 163133980712
# 186941941714
# 159531167997
# 159531167997
# 046922558887
# 943063077874
# 792389774673
# 167695383458
# Iz.:999893751750
# Kl.:838901042770
# 06EYD876
# 143860010348
# Ei:556799175487
# 143860010348
# Un:705491035775
# 143860010348
# Kh:360595695159
# 143860010348
# Kh:217952887271
# 35615904922
# 696135165639
# Vw.:403489591437
# 141774671173
# 747051878431
# 779875708882
# 800306846075
# 955487471144
# 276795361801
# 276795361801
# 034626995785
# VZ:775Y6A5764
# DM:705244534902
# 132305666219
# 789323889085
# 762035863358
# 188408534931
# nMFtUVxSUI|33529258
# nMFtUVxSUI|33529258
# 51,00,23,0
# 342998677810
# 522233062166
# 843756944804
# 493950392533
# 183169291463
# 172801513686
# 172801513686
# 208798413907
# 347376430553
# 943995368223
# 027693
# ras21
# 723847538279
# 534516353860
# 871483046449
# 836172426340
# 369615882777
# 014674070485
# 264945858442
# 320622779078
# Weyhacy_7000693584
# 047378465
# 047378465
# IV-8322
# IV-8322
# Z.S.
# 30407059
# V69230
